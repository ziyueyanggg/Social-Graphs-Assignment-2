# %%
import re
import io
import glob
import nltk
import string
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('figure', figsize=(12, 6))
import math
from fa2 import ForceAtlas2
from collections import Counter

# %% [markdown]
# # Part 1: Twitter Network Analysis

# %% [markdown]
# ## Exercise 1: Build the network of retweets
# We will now build a network that has as nodes the Twitter handles of the members of the house, and direct edges between nodes A and B if A has retweeted content posted by B. We will build a weighted network, where the weight of an edge is equal to the number of retweets. You can build the network following the steps below (and you should be able to reuse many of the functions you have written as part of the exercises during the previous weeks):

# %% [markdown]
# * **Consider the 200 most recent tweets written by each member of the house (use the files [here](https://github.com/suneman/socialgraphs2019/tree/master/files/data_twitter/tweets_2019.zip/). For each file, use a regular expression to find retweets and to extract the Twitter handle of the user whose content was retweeted. All retweets begin with "*RT @originalAuthor:*", where "*originalAuthor*" is the handle of the user whose content was retweeted (and the part of the text you want to extract).**

# %% [markdown]
# *According to Twitter offical page (https://help.twitter.com/en/managing-your-account/twitter-username-rules), Twitter handles can only contain letters, digits and underscores. This explains the regular expression pattern we choose to use below.*

# %%
# define a function to find the original author and the content of ONE member's retweets 

def find_retweets(path):
    
    # first, read the tweets of a particular member
    # io module is chosen for its encoding parameter as utf-8 encoding is needed
    f = io.open(path, mode="r", encoding="utf-8").read()
    
    # then, use regex to find all retweets of this member
    # result is stored in a tuple of tuples of the following format: 
    # ((originalAuthor1, content1),(originalAuthor2, content2),...)
    tup = re.findall(r"RT @([a-zA-Z0-9_]+): (.*)", f) # letter, digit and underscore

    return tup

# %% [markdown]
# * For each retweet, check if the handle retweeted is, in fact, the handle of a member of the house. If yes, keep it. If no, discard it.

# %%
# load Twitter handles of the members of the house
members_df = pd.read_csv("H115_tw_2019.csv")
members_df.head()
# Out:
#                           WikiPageName       Party       State  \
# 0                            Don_Young  Republican      Alaska
# 1                    Jim_Sensenbrenner  Republican   Wisconsin
# 2                           Hal_Rogers  Republican    Kentucky
# 3  Chris_Smith_(New_Jersey_politician)  Republican  New Jersey
# 4                          Steny_Hoyer  Democratic    Maryland
#
#                 Name         tw_id         tw_name
# 0          Don Young  3.700727e+07     repdonyoung
# 1  Jim Sensenbrenner  8.516214e+08  JimPressOffice
# 2         Hal Rogers  5.504018e+08    RepHalRogers
# 3        Chris Smith  1.289319e+09   RepChrisSmith
# 4        Steny Hoyer  2.201209e+07     LeaderHoyer

# %% [markdown]
# *Create three dictionaries for convertering between various member information:*

# %%
# some data extraction to build dictionary
tw_name = members_df.tw_name.tolist()
party=members_df.Party.tolist()
wiki_name=members_df.WikiPageName.tolist()

# %%
# dictionary that maps wikiname to party
wikiName_party_dic={}

for i in range(len(wiki_name)):
    wikiName_party_dic[wiki_name[i]] = party[i]

wikiName_party_dic
# Out:
# {'Don_Young': 'Republican',
#  'Jim_Sensenbrenner': 'Republican',
#  'Hal_Rogers': 'Republican',
#  'Chris_Smith_(New_Jersey_politician)': 'Republican',
#  'Steny_Hoyer': 'Democratic',
#  'Marcy_Kaptur': 'Democratic',
#  'Pete_Visclosky': 'Democratic',
#  'Peter_DeFazio': 'Democratic',
#  'John_Lewis_(civil_rights_leader)': 'Democratic',
#  'Fred_Upton': 'Republican',
#  'Nancy_Pelosi': 'Democratic',
#  'Frank_Pallone': 'Democratic',
#  'Eliot_Engel': 'Democratic',
#  'Nita_Lowey': 'Democratic',
#  'Richard_Neal': 'Democratic',
#  'José_E._Serrano': 'Democratic',
#  'David_Price_(American_politician)': 'Democratic',
#  'Rosa_DeLauro': 'Democratic',
#  'Maxine_Waters': 'Democratic',
#  'Jerrold_Nadler': 'Democratic',
#  'Jim_Cooper': 'Democratic',
#  'Ken_Calvert': 'Republican',
#  'Jim_Clyburn': 'Democratic',
#  'Anna_Eshoo': 'Democratic',
#  'Gene_Green': 'Democratic',
#  'Alcee_Hastings': 'Democratic',
#  'Peter_T._King': 'Republican',
#  'Carolyn_Maloney': 'Democratic',
#  'Lucille_Roybal-Allard': 'Democratic',
#  'Bobby_Rush': 'Democratic',
#  'Bobby_Scott_(politician)': 'Democratic',
#  'Bennie_Thompson': 'Democratic',
#  'Frank_Lucas_(Oklahoma_politician)': 'Republican',
#  'Lloyd_Doggett': 'Democratic',
#  'Michael_F._Doyle': 'Democratic',
#  'Sheila_Jackson_Lee': 'Democratic',
#  'Zoe_Lofgren': 'Democratic',
#  'Mac_Thornberry': 'Republican',
#  'Elijah_Cummings': 'Democratic',
#  'Earl_Blumenauer': 'Democratic',
#  'Robert_Aderholt': 'Republican',
#  'Kevin_Brady': 'Republican',
#  'Danny_K._Davis': 'Democratic',
#  'Diana_DeGette': 'Democratic',
#  'Kay_Granger': 'Republican',
#  'Ron_Kind': 'Democratic',
#  'Jim_McGovern_(American_politician)': 'Democratic',
#  'Bill_Pascrell': 'Democratic',
#  'Brad_Sherman': 'Democratic',
#  'John_Shimkus': 'Republican',
#  'Adam_Smith_(politician)': 'Democratic',
#  'Gregory_Meeks': 'Democratic',
#  'Barbara_Lee': 'Democratic',
#  'Steve_Chabot': 'Republican',
#  'Joe_Crowley': 'Democratic',
#  'John_B._Larson': 'Democratic',
#  'Grace_Napolitano': 'Democratic',
#  'Jan_Schakowsky': 'Democratic',
#  'Mike_Simpson': 'Republican',
#  'Mike_Thompson_(California_politician)': 'Democratic',
#  'Greg_Walden': 'Republican',
#  'Lacy_Clay': 'Democratic',
#  'Susan_Davis_(politician)': 'Democratic',
#  'Sam_Graves': 'Republican',
#  'James_Langevin': 'Democratic',
#  'Rick_Larsen': 'Democratic',
#  'Betty_McCollum': 'Democratic',
#  'Adam_Schiff': 'Democratic',
#  'Pat_Tiberi': 'Republican',
#  'Stephen_F._Lynch': 'Democratic',
#  'Joe_Wilson_(American_politician)': 'Republican',
#  'Rob_Bishop': 'Republican',
#  'Michael_C._Burgess': 'Republican',
#  'John_Carter_(Texas_politician)': 'Republican',
#  'Tom_Cole': 'Republican',
#  'Raúl_Grijalva': 'Democratic',
#  'Steve_King': 'Republican',
#  'Tim_Murphy_(American_politician)': 'Republican',
#  'Devin_Nunes': 'Republican',
#  'Mike_Rogers_(Alabama_politician)': 'Republican',
#  'Dutch_Ruppersberger': 'Democratic',
#  'Tim_Ryan_(politician)': 'Democratic',
#  'Linda_Sánchez': 'Democratic',
#  'David_Scott_(Georgia_politician)': 'Democratic',
#  'Mike_Turner': 'Republican',
#  'G._K._Butterfield': 'Democratic',
#  'Emanuel_Cleaver': 'Democratic',
#  'Mike_Conaway': 'Republican',
#  'Jim_Costa': 'Democratic',
#  'Henry_Cuellar': 'Democratic',
#  'Jeff_Fortenberry': 'Republican',
#  'Virginia_Foxx': 'Republican',
#  'Louie_Gohmert': 'Republican',
#  'Al_Green_(politician)': 'Democratic',
#  'Brian_Higgins': 'Democratic',
#  'Dan_Lipinski': 'Democratic',
#  'Kenny_Marchant': 'Republican',
#  'Michael_McCaul': 'Republican',
#  'Patrick_McHenry': 'Republican',
#  'Cathy_McMorris_Rodgers': 'Republican',
#  'Gwen_Moore': 'Democratic',
#  'Debbie_Wasserman_Schultz': 'Democratic',
#  'Doris_Matsui': 'Democratic',
#  'Albio_Sires': 'Democratic',
#  'Gus_Bilirakis': 'Republican',
#  'Vern_Buchanan': 'Republican',
#  'Kathy_Castor': 'Democratic',
#  'Yvette_Clarke': 'Democratic',
#  'Steve_Cohen': 'Democratic',
#  'Joe_Courtney_(politician)': 'Democratic',
#  'Hank_Johnson': 'Democratic',
#  'Jim_Jordan_(American_politician)': 'Republican',
#  'Doug_Lamborn': 'Republican',
#  'Dave_Loebsack': 'Democratic',
#  'Kevin_McCarthy_(California_politician)': 'Republican',
#  'Jerry_McNerney': 'Democratic',
#  'Ed_Perlmutter': 'Democratic',
#  'Pete_Roskam': 'Republican',
#  'John_Sarbanes': 'Democratic',
#  'Adrian_Smith_(politician)': 'Republican',
#  'Tim_Walz': 'Democratic',
#  'Peter_Welch': 'Democratic',
#  'John_Yarmuth': 'Democratic',
#  'Bob_Latta': 'Republican',
#  'Rob_Wittman': 'Republican',
#  'André_Carson': 'Democratic',
#  'Jackie_Speier': 'Democratic',
#  'Steve_Scalise': 'Republican',
#  'Marcia_Fudge': 'Democratic',
#  'Gerry_Connolly': 'Democratic',
#  'Brett_Guthrie': 'Republican',
#  'Jim_Himes': 'Democratic',
#  'Duncan_D._Hunter': 'Republican',
#  'Blaine_Luetkemeyer': 'Republican',
#  'Ben_Ray_Luján': 'Democratic',
#  'Tom_McClintock': 'Republican',
#  'Pete_Olson': 'Republican',
#  'Chellie_Pingree': 'Democratic',
#  'Bill_Posey': 'Republican',
#  'Phil_Roe_(politician)': 'Republican',
#  'Kurt_Schrader': 'Democratic',
#  'Glenn_Thompson_(politician)': 'Republican',
#  'Paul_Tonko': 'Democratic',
#  'Mike_Quigley_(politician)': 'Democratic',
#  'Judy_Chu': 'Democratic',
#  'John_Garamendi': 'Democratic',
#  'Ted_Deutch': 'Democratic',
#  'Tom_Graves': 'Republican',
#  'Tom_Reed_(politician)': 'Republican',
#  'Tim_Walberg': 'Republican',
#  'Bill_Foster_(politician)': 'Democratic',
#  'Justin_Amash': 'Republican',
#  'Karen_Bass': 'Democratic',
#  'Mo_Brooks': 'Republican',
#  'Larry_Bucshon': 'Republican',
#  'David_Cicilline': 'Democratic',
#  'Rick_Crawford_(politician)': 'Republican',
#  'Scott_DesJarlais': 'Republican',
#  'Jeff_Duncan_(politician)': 'Republican',
#  'Chuck_Fleischmann': 'Republican',
#  'Bill_Flores': 'Republican',
#  'Bob_Gibbs': 'Republican',
#  'Paul_Gosar': 'Republican',
#  'Morgan_Griffith': 'Republican',
#  'Andy_Harris_(politician)': 'Republican',
#  'Vicky_Hartzler': 'Republican',
#  'Jaime_Herrera_Beutler': 'Republican',
#  'Bill_Huizenga': 'Republican',
#  'Bill_Johnson_(Ohio_politician)': 'Republican',
#  'Bill_Keating_(politician)': 'Democratic',
#  'Mike_Kelly_(Pennsylvania_politician)': 'Republican',
#  'Adam_Kinzinger': 'Republican',
#  'Billy_Long': 'Republican',
#  'David_McKinley': 'Republican',
#  'Steven_Palazzo': 'Republican',
#  'Cedric_Richmond': 'Democratic',
#  'Martha_Roby': 'Republican',
#  'Dennis_Ross_(politician)': 'Republican',
#  'David_Schweikert': 'Republican',
#  'Austin_Scott_(politician)': 'Republican',
#  'Terri_Sewell': 'Democratic',
#  'Steve_Stivers': 'Republican',
#  'Scott_Tipton': 'Republican',
#  'Daniel_Webster_(Florida_politician)': 'Republican',
#  'Frederica_Wilson': 'Democratic',
#  'Steve_Womack': 'Republican',
#  'Rob_Woodall': 'Republican',
#  'Mark_Amodei': 'Republican',
#  'Suzanne_Bonamici': 'Democratic',
#  'Suzan_DelBene': 'Democratic',
#  'Thomas_Massie': 'Republican',
#  'Dina_Titus': 'Democratic',
#  'Andy_Barr_(American_politician)': 'Republican',
#  'Joyce_Beatty': 'Democratic',
#  'Ami_Bera': 'Democratic',
#  'Susan_Brooks': 'Republican',
#  'Julia_Brownley': 'Democratic',
#  'Cheri_Bustos': 'Democratic',
#  'Tony_Cárdenas': 'Democratic',
#  'Matt_Cartwright': 'Democratic',
#  'Joaquín_Castro': 'Democratic',
#  'Doug_Collins_(politician)': 'Republican',
#  'Paul_Cook_(politician)': 'Republican',
#  'Rodney_Davis_(politician)': 'Republican',
#  'Lois_Frankel': 'Democratic',
#  'Tulsi_Gabbard': 'Democratic',
#  'Dennis_Heck': 'Democratic',
#  'George_Holding': 'Republican',
#  'Richard_Hudson_(American_politician)': 'Republican',
#  'Jared_Huffman': 'Democratic',
#  'Hakeem_Jeffries': 'Democratic',
#  'Joe_Kennedy_III': 'Democratic',
#  'Dan_Kildee': 'Democratic',
#  'Derek_Kilmer': 'Democratic',
#  'Ann_McLane_Kuster': 'Democratic',
#  'Doug_LaMalfa': 'Republican',
#  'Alan_Lowenthal': 'Democratic',
#  'Sean_Patrick_Maloney': 'Democratic',
#  'Mark_Meadows_(North_Carolina_politician)': 'Republican',
#  'Grace_Meng': 'Democratic',
#  'Markwayne_Mullin': 'Republican',
#  'Scott_Perry_(politician)': 'Republican',
#  'Scott_Peters_(politician)': 'Democratic',
#  'Mark_Pocan': 'Democratic',
#  'Tom_Rice': 'Republican',
#  'Keith_Rothfus': 'Republican',
#  'Raul_Ruiz_(politician)': 'Democratic',
#  'Chris_Stewart_(politician)': 'Republican',
#  'Eric_Swalwell': 'Democratic',
#  'Mark_Takano': 'Democratic',
#  'Juan_Vargas': 'Democratic',
#  'Marc_Veasey': 'Democratic',
#  'Ann_Wagner': 'Republican',
#  'Jackie_Walorski': 'Republican',
#  'Randy_Weber': 'Republican',
#  'Brad_Wenstrup': 'Republican',
#  'Roger_Williams_(American_politician)': 'Republican',
#  'Ted_Yoho': 'Republican',
#  'Robin_Kelly': 'Democratic',
#  'Jason_Smith_(politician)': 'Republican',
#  'Katherine_Clark': 'Democratic',
#  'Bradley_Byrne': 'Republican',
#  'Donald_Norcross': 'Democratic',
#  'Ralph_Abraham_(politician)': 'Republican',
#  'Pete_Aguilar': 'Democratic',
#  'Rick_W._Allen': 'Republican',
#  'Brian_Babin': 'Republican',
#  'Don_Beyer': 'Democratic',
#  'Mike_Bost': 'Republican',
#  'Brendan_Boyle': 'Democratic',
#  'Ken_Buck': 'Republican',
#  'Buddy_Carter': 'Republican',
#  'Mark_DeSaulnier': 'Democratic',
#  'Debbie_Dingell': 'Democratic',
#  'Tom_Emmer': 'Republican',
#  'Ruben_Gallego': 'Democratic',
#  'Garret_Graves': 'Republican',
#  'Glenn_Grothman': 'Republican',
#  'Jody_Hice': 'Republican',
#  'French_Hill_(politician)': 'Republican',
#  'Will_Hurd': 'Republican',
#  'John_Katko': 'Republican',
#  'Brenda_Lawrence': 'Democratic',
#  'Ted_Lieu': 'Democratic',
#  'Barry_Loudermilk': 'Republican',
#  'John_Moolenaar': 'Republican',
#  'Alex_Mooney': 'Republican',
#  'Seth_Moulton': 'Democratic',
#  'Dan_Newhouse': 'Republican',
#  'Gary_Palmer_(politician)': 'Republican',
#  'John_Ratcliffe_(American_politician)': 'Republican',
#  'Kathleen_Rice': 'Democratic',
#  'David_Rouzer': 'Republican',
#  'Elise_Stefanik': 'Republican',
#  'Norma_Torres': 'Democratic',
#  'Mark_Walker_(North_Carolina_politician)': 'Republican',
#  'Bonnie_Watson_Coleman': 'Democratic',
#  'Bruce_Westerman': 'Republican',
#  'Lee_Zeldin': 'Republican',
#  'Trent_Kelly': 'Republican',
#  'Darin_LaHood': 'Republican',
#  'Warren_Davidson': 'Republican',
#  'James_Comer_(politician)': 'Republican',
#  'Dwight_Evans_(politician)': 'Democratic',
#  'Brad_Schneider': 'Democratic',
#  'Jodey_Arrington': 'Republican',
#  'Don_Bacon_(politician)': 'Republican',
#  'Jim_Banks': 'Republican',
#  'Nanette_Barragán': 'Democratic',
#  'Jack_Bergman': 'Republican',
#  'Andy_Biggs': 'Republican',
#  'Lisa_Blunt_Rochester': 'Democratic',
#  'Anthony_G._Brown': 'Democratic',
#  'Ted_Budd': 'Republican',
#  'Salud_Carbajal': 'Democratic',
#  'Liz_Cheney': 'Republican',
#  'Lou_Correa': 'Democratic',
#  'Charlie_Crist': 'Democratic',
#  'Val_Demings': 'Democratic',
#  'Neal_Dunn': 'Republican',
#  'Adriano_Espaillat': 'Democratic',
#  'Drew_Ferguson_(politician)': 'Republican',
#  'Brian_Fitzpatrick_(American_politician)': 'Republican',
#  'Matt_Gaetz': 'Republican',
#  'Mike_Gallagher_(American_politician)': 'Republican',
#  'Josh_Gottheimer': 'Democratic',
#  'Clay_Higgins': 'Republican',
#  'Trey_Hollingsworth': 'Republican',
#  'Pramila_Jayapal': 'Democratic',
#  'Mike_Johnson_(Louisiana_politician)': 'Republican',
#  'Ro_Khanna': 'Democratic',
#  'Raja_Krishnamoorthi': 'Democratic',
#  'David_Kustoff': 'Republican',
#  'Al_Lawson': 'Democratic',
#  'Roger_Marshall_(politician)': 'Republican',
#  'Brian_Mast': 'Republican',
#  'Donald_McEachin': 'Democratic',
#  'Paul_Mitchell_(politician)': 'Republican',
#  'Stephanie_Murphy': 'Democratic',
#  "Tom_O'Halleran": 'Democratic',
#  'Jimmy_Panetta': 'Democratic',
#  'Jamie_Raskin': 'Democratic',
#  'Francis_Rooney': 'Republican',
#  'John_Rutherford_(Florida_politician)': 'Republican',
#  'Lloyd_Smucker': 'Republican',
#  'Darren_Soto': 'Democratic',
#  'Thomas_Suozzi': 'Democratic',
#  'Scott_Taylor_(politician)': 'Republican',
#  'Ron_Estes': 'Republican',
#  'Jimmy_Gomez': 'Democratic',
#  'Ralph_Norman': 'Republican',
#  'John_Curtis_(American_politician)': 'Republican',
#  'Conor_Lamb': 'Democratic',
#  'Debbie_Lesko': 'Republican',
#  'Michael_Cloud': 'Republican',
#  'Troy_Balderson': 'Republican'}

# %%
# dictionary that maps tw_name to party
twName_party_dic={}

for i in range(len(tw_name)):
    twName_party_dic[tw_name[i]] = party[i]

twName_party_dic
# Out:
# {'repdonyoung': 'Republican',
#  'JimPressOffice': 'Republican',
#  'RepHalRogers': 'Republican',
#  'RepChrisSmith': 'Republican',
#  'LeaderHoyer': 'Democratic',
#  'RepMarcyKaptur': 'Democratic',
#  'RepVisclosky': 'Democratic',
#  'RepPeterDeFazio': 'Democratic',
#  'repjohnlewis': 'Democratic',
#  'RepFredUpton': 'Republican',
#  'SpeakerPelosi': 'Democratic',
#  'FrankPallone': 'Democratic',
#  'RepEliotEngel': 'Democratic',
#  'NitaLowey': 'Democratic',
#  'RepRichardNeal': 'Democratic',
#  'RepJoseSerrano': 'Democratic',
#  'RepDavidEPrice': 'Democratic',
#  'rosadelauro': 'Democratic',
#  'RepMaxineWaters': 'Democratic',
#  'RepJerryNadler': 'Democratic',
#  'repjimcooper': 'Democratic',
#  'KenCalvert': 'Republican',
#  'WhipClyburn': 'Democratic',
#  'RepAnnaEshoo': 'Democratic',
#  'RepMarkGreen': 'Democratic',
#  'RepHastingsFL': 'Democratic',
#  'RepPeteKing': 'Republican',
#  'RepMaloney': 'Democratic',
#  'RepRoybalAllard': 'Democratic',
#  'RepBobbyRush': 'Democratic',
#  'BobbyScott': 'Democratic',
#  'BennieGThompson': 'Democratic',
#  'RepFrankLucas': 'Republican',
#  'RepLloydDoggett': 'Democratic',
#  'USRepMikeDoyle': 'Democratic',
#  'JacksonLeeTX18': 'Democratic',
#  'RepZoeLofgren': 'Democratic',
#  'MacTXPress': 'Republican',
#  'RepCummings': 'Democratic',
#  'repblumenauer': 'Democratic',
#  'Robert_Aderholt': 'Republican',
#  'RepKevinBrady': 'Republican',
#  'RepDannyDavis': 'Democratic',
#  'RepDianaDeGette': 'Democratic',
#  'RepKayGranger': 'Republican',
#  'RepRonKind': 'Democratic',
#  'RepMcGovern': 'Democratic',
#  'BillPascrell': 'Democratic',
#  'BradSherman': 'Democratic',
#  'RepShimkus': 'Republican',
#  'RepAdamSmith': 'Democratic',
#  'RepGregoryMeeks': 'Democratic',
#  'RepBarbaraLee': 'Democratic',
#  'RepSteveChabot': 'Republican',
#  'JoeCrowleyNY': 'Democratic',
#  'RepJohnLarson': 'Democratic',
#  'gracenapolitano': 'Democratic',
#  'janschakowsky': 'Democratic',
#  'CongMikeSimpson': 'Republican',
#  'RepThompson': 'Democratic',
#  'repgregwalden': 'Republican',
#  'LacyClayMO1': 'Democratic',
#  'RepSusanDavis': 'Democratic',
#  'RepSamGraves': 'Republican',
#  'JimLangevin': 'Democratic',
#  'RepRickLarsen': 'Democratic',
#  'BettyMcCollum04': 'Democratic',
#  'RepAdamSchiff': 'Democratic',
#  'PatTiberi': 'Republican',
#  'RepStephenLynch': 'Democratic',
#  'RepJoeWilson': 'Republican',
#  'RepRobBishop': 'Republican',
#  'michaelcburgess': 'Republican',
#  'JudgeCarter': 'Republican',
#  'TomColeOK04': 'Republican',
#  'RepRaulGrijalva': 'Democratic',
#  'SteveKingIA': 'Republican',
#  'RepGregMurphy': 'Republican',
#  'RepDevinNunes': 'Republican',
#  'RepMikeRogersAL': 'Republican',
#  'Call_Me_Dutch': 'Democratic',
#  'RepTimRyan': 'Democratic',
#  'RepLindaSanchez': 'Democratic',
#  'repdavidscott': 'Democratic',
#  'RepMikeTurner': 'Republican',
#  'GKButterfield': 'Democratic',
#  'repcleaver': 'Democratic',
#  'ConawayTX11': 'Republican',
#  'RepJimCosta': 'Democratic',
#  'RepCuellar': 'Democratic',
#  'JeffFortenberry': 'Republican',
#  'virginiafoxx': 'Republican',
#  'replouiegohmert': 'Republican',
#  'RepAlGreen': 'Democratic',
#  'RepBrianHiggins': 'Democratic',
#  'RepLipinski': 'Democratic',
#  'RepKenMarchant': 'Republican',
#  'RepMcCaul': 'Republican',
#  'PatrickMcHenry': 'Republican',
#  'cathymcmorris': 'Republican',
#  'RepGwenMoore': 'Democratic',
#  'RepDWStweets': 'Democratic',
#  'DorisMatsui': 'Democratic',
#  'RepSires': 'Democratic',
#  'RepGusBilirakis': 'Republican',
#  'VernBuchanan': 'Republican',
#  'USRepKCastor': 'Democratic',
#  'RepYvetteClarke': 'Democratic',
#  'RepCohen': 'Democratic',
#  'RepJoeCourtney': 'Democratic',
#  'RepHankJohnson': 'Democratic',
#  'Jim_Jordan': 'Republican',
#  'RepDLamborn': 'Republican',
#  'daveloebsack': 'Democratic',
#  'GOPLeader': 'Republican',
#  'RepMcNerney': 'Democratic',
#  'RepPerlmutter': 'Democratic',
#  'PeterRoskam': 'Republican',
#  'RepSarbanes': 'Democratic',
#  'RepAdrianSmith': 'Republican',
#  'Tim_Walz': 'Democratic',
#  'PeterWelch': 'Democratic',
#  'RepJohnYarmuth': 'Democratic',
#  'boblatta': 'Republican',
#  'RobWittman': 'Republican',
#  'RepAndreCarson': 'Democratic',
#  'RepSpeier': 'Democratic',
#  'SteveScalise': 'Republican',
#  'RepMarciaFudge': 'Democratic',
#  'GerryConnolly': 'Democratic',
#  'RepGuthrie': 'Republican',
#  'jahimes': 'Democratic',
#  'Rep_Hunter': 'Republican',
#  'RepBlaine': 'Republican',
#  'repbenraylujan': 'Democratic',
#  'RepMcClintock': 'Republican',
#  'RepPeteOlson': 'Republican',
#  'chelliepingree': 'Democratic',
#  'congbillposey': 'Republican',
#  'DrPhilRoe': 'Republican',
#  'RepSchrader': 'Democratic',
#  'CongressmanGT': 'Republican',
#  'RepPaulTonko': 'Democratic',
#  'RepMikeQuigley': 'Democratic',
#  'RepJudyChu': 'Democratic',
#  'RepGaramendi': 'Democratic',
#  'RepTedDeutch': 'Democratic',
#  'RepTomGraves': 'Republican',
#  'RepTomReed': 'Republican',
#  'RepWalberg': 'Republican',
#  'RepBillFoster': 'Democratic',
#  'justinamash': 'Republican',
#  'RepKarenBass': 'Democratic',
#  'RepMoBrooks': 'Republican',
#  'RepLarryBucshon': 'Republican',
#  'davidcicilline': 'Democratic',
#  'RepRickCrawford': 'Republican',
#  'DesJarlaisTN04': 'Republican',
#  'RepJeffDuncan': 'Republican',
#  'RepChuck': 'Republican',
#  'RepBillFlores': 'Republican',
#  'RepBobGibbs': 'Republican',
#  'RepGosar': 'Republican',
#  'RepMGriffith': 'Republican',
#  'RepAndyHarrisMD': 'Republican',
#  'RepHartzler': 'Republican',
#  'HerreraBeutler': 'Republican',
#  'RepHuizenga': 'Republican',
#  'RepBillJohnson': 'Republican',
#  'USRepKeating': 'Democratic',
#  'MikeKellyPA': 'Republican',
#  'RepKinzinger': 'Republican',
#  'USRepLong': 'Republican',
#  'RepMcKinley': 'Republican',
#  'CongPalazzo': 'Republican',
#  'RepRichmond': 'Democratic',
#  'RepMarthaRoby': 'Republican',
#  'RepRossSpano': 'Republican',
#  'RepDavid': 'Republican',
#  'AustinScottGA08': 'Republican',
#  'RepTerriSewell': 'Democratic',
#  'RepSteveStivers': 'Republican',
#  'RepTipton': 'Republican',
#  'RepWebster': 'Republican',
#  'RepWilson': 'Democratic',
#  'rep_stevewomack': 'Republican',
#  'RepRobWoodall': 'Republican',
#  'MarkAmodeiNV2': 'Republican',
#  'RepBonamici': 'Democratic',
#  'RepDelBene': 'Democratic',
#  'RepThomasMassie': 'Republican',
#  'repdinatitus': 'Democratic',
#  'RepAndyBarr': 'Republican',
#  'RepBeatty': 'Democratic',
#  'RepBera': 'Democratic',
#  'SusanWBrooks': 'Republican',
#  'RepBrownley': 'Democratic',
#  'RepCheri': 'Democratic',
#  'RepCardenas': 'Democratic',
#  'RepCartwright': 'Democratic',
#  'JoaquinCastrotx': 'Democratic',
#  'RepDougCollins': 'Republican',
#  'RepPaulCook': 'Republican',
#  'RodneyDavis': 'Republican',
#  'RepLoisFrankel': 'Democratic',
#  'TulsiPress': 'Democratic',
#  'RepDennyHeck': 'Democratic',
#  'RepHolding': 'Republican',
#  'RepRichHudson': 'Republican',
#  'RepHuffman': 'Democratic',
#  'RepJeffries': 'Democratic',
#  'RepJoeKennedy': 'Democratic',
#  'RepDanKildee': 'Democratic',
#  'RepDerekKilmer': 'Democratic',
#  'RepAnnieKuster': 'Democratic',
#  'RepLaMalfa': 'Republican',
#  'RepLowenthal': 'Democratic',
#  'RepSeanMaloney': 'Democratic',
#  'RepMarkMeadows': 'Republican',
#  'RepGraceMeng': 'Democratic',
#  'RepMullin': 'Republican',
#  'RepScottPerry': 'Republican',
#  'RepScottPeters': 'Democratic',
#  'repmarkpocan': 'Democratic',
#  'RepTomRice': 'Republican',
#  'RothfusForPA': 'Republican',
#  'CongressmanRuiz': 'Democratic',
#  'RepChrisStewart': 'Republican',
#  'RepSwalwell': 'Democratic',
#  'RepMarkTakano': 'Democratic',
#  'RepJuanVargas': 'Democratic',
#  'RepVeasey': 'Democratic',
#  'RepAnnWagner': 'Republican',
#  'RepWalorski': 'Republican',
#  'TXRandy14': 'Republican',
#  'RepBradWenstrup': 'Republican',
#  'RepRWilliams': 'Republican',
#  'RepTedYoho': 'Republican',
#  'RepRobinKelly': 'Democratic',
#  'RepJasonSmith': 'Republican',
#  'RepKClark': 'Democratic',
#  'RepByrne': 'Republican',
#  'DonaldNorcross': 'Democratic',
#  'RepAbraham': 'Republican',
#  'RepPeteAguilar': 'Democratic',
#  'RepRickAllen': 'Republican',
#  'RepBrianBabin': 'Republican',
#  'RepDonBeyer': 'Democratic',
#  'RepBost': 'Republican',
#  'RepBrendanBoyle': 'Democratic',
#  'RepKenBuck': 'Republican',
#  'RepBuddyCarter': 'Republican',
#  'RepDeSaulnier': 'Democratic',
#  'RepDebDingell': 'Democratic',
#  'RepTomEmmer': 'Republican',
#  'RepRubenGallego': 'Democratic',
#  'RepGarretGraves': 'Republican',
#  'RepGrothman': 'Republican',
#  'CongressmanHice': 'Republican',
#  'RepFrenchHill': 'Republican',
#  'HurdOnTheHill': 'Republican',
#  'RepJohnKatko': 'Republican',
#  'RepLawrence': 'Democratic',
#  'RepTedLieu': 'Democratic',
#  'RepLoudermilk': 'Republican',
#  'RepMoolenaar': 'Republican',
#  'RepAlexMooney': 'Republican',
#  'sethmoulton': 'Democratic',
#  'RepNewhouse': 'Republican',
#  'USRepGaryPalmer': 'Republican',
#  'RepRatcliffe': 'Republican',
#  'RepKathleenRice': 'Democratic',
#  'RepDavidRouzer': 'Republican',
#  'RepStefanik': 'Republican',
#  'NormaJTorres': 'Democratic',
#  'RepMarkWalker': 'Republican',
#  'RepBonnie': 'Democratic',
#  'RepWesterman': 'Republican',
#  'RepLeeZeldin': 'Republican',
#  'RepTrentKelly': 'Republican',
#  'RepLaHood': 'Republican',
#  'WarrenDavidson': 'Republican',
#  'KYComer': 'Republican',
#  'RepDwightEvans': 'Democratic',
#  'RepSchneider': 'Democratic',
#  'RepArrington': 'Republican',
#  'RepDonBacon': 'Republican',
#  'RepJimBanks': 'Republican',
#  'RepBarragan': 'Democratic',
#  'RepJackBergman': 'Republican',
#  'RepAndyBiggsAZ': 'Republican',
#  'RepLBR': 'Democratic',
#  'RepAnthonyBrown': 'Democratic',
#  'RepTedBudd': 'Republican',
#  'RepCarbajal': 'Democratic',
#  'RepLizCheney': 'Republican',
#  'RepLouCorrea': 'Democratic',
#  'RepCharlieCrist': 'Democratic',
#  'RepValDemings': 'Democratic',
#  'DrNealDunnFL2': 'Republican',
#  'RepEspaillat': 'Democratic',
#  'RepDrewFerguson': 'Republican',
#  'RepBrianFitz': 'Republican',
#  'RepMattGaetz': 'Republican',
#  'RepGallagher': 'Republican',
#  'RepJoshG': 'Democratic',
#  'RepClayHiggins': 'Republican',
#  'RepTrey': 'Republican',
#  'RepJayapal': 'Democratic',
#  'RepMikeJohnson': 'Republican',
#  'RepRoKhanna': 'Democratic',
#  'CongressmanRaja': 'Democratic',
#  'RepDavidKustoff': 'Republican',
#  'RepAlLawsonJr': 'Democratic',
#  'RepMarshall': 'Republican',
#  'RepBrianMast': 'Republican',
#  'RepMcEachin': 'Democratic',
#  'RepPaulMitchell': 'Republican',
#  'RepStephMurphy': 'Democratic',
#  'RepOHalleran': 'Democratic',
#  'RepJimmyPanetta': 'Democratic',
#  'RepRaskin': 'Democratic',
#  'RepRooney': 'Republican',
#  'RepRutherfordFL': 'Republican',
#  'RepSmucker': 'Republican',
#  'RepDarrenSoto': 'Democratic',
#  'RepTomSuozzi': 'Democratic',
#  'RepVanTaylor': 'Republican',
#  'RepRonEstes': 'Republican',
#  'RepJimmyGomez': 'Democratic',
#  'RepRalphNorman': 'Republican',
#  'RepJohnCurtis': 'Republican',
#  'RepConorLamb': 'Democratic',
#  'RepDLesko': 'Republican',
#  'RepCloudTX': 'Republican',
#  'RepBalderson': 'Republican'}

# %%
# dictionary that maps wikiname to tw_name
wikiname_twName_dic={}

for i in range(len(tw_name)):
    wikiname_twName_dic[wiki_name[i]] = tw_name[i]

wikiname_twName_dic
# Out:
# {'Don_Young': 'repdonyoung',
#  'Jim_Sensenbrenner': 'JimPressOffice',
#  'Hal_Rogers': 'RepHalRogers',
#  'Chris_Smith_(New_Jersey_politician)': 'RepChrisSmith',
#  'Steny_Hoyer': 'LeaderHoyer',
#  'Marcy_Kaptur': 'RepMarcyKaptur',
#  'Pete_Visclosky': 'RepVisclosky',
#  'Peter_DeFazio': 'RepPeterDeFazio',
#  'John_Lewis_(civil_rights_leader)': 'repjohnlewis',
#  'Fred_Upton': 'RepFredUpton',
#  'Nancy_Pelosi': 'SpeakerPelosi',
#  'Frank_Pallone': 'FrankPallone',
#  'Eliot_Engel': 'RepEliotEngel',
#  'Nita_Lowey': 'NitaLowey',
#  'Richard_Neal': 'RepRichardNeal',
#  'José_E._Serrano': 'RepJoseSerrano',
#  'David_Price_(American_politician)': 'RepDavidEPrice',
#  'Rosa_DeLauro': 'rosadelauro',
#  'Maxine_Waters': 'RepMaxineWaters',
#  'Jerrold_Nadler': 'RepJerryNadler',
#  'Jim_Cooper': 'repjimcooper',
#  'Ken_Calvert': 'KenCalvert',
#  'Jim_Clyburn': 'WhipClyburn',
#  'Anna_Eshoo': 'RepAnnaEshoo',
#  'Gene_Green': 'RepMarkGreen',
#  'Alcee_Hastings': 'RepHastingsFL',
#  'Peter_T._King': 'RepPeteKing',
#  'Carolyn_Maloney': 'RepMaloney',
#  'Lucille_Roybal-Allard': 'RepRoybalAllard',
#  'Bobby_Rush': 'RepBobbyRush',
#  'Bobby_Scott_(politician)': 'BobbyScott',
#  'Bennie_Thompson': 'BennieGThompson',
#  'Frank_Lucas_(Oklahoma_politician)': 'RepFrankLucas',
#  'Lloyd_Doggett': 'RepLloydDoggett',
#  'Michael_F._Doyle': 'USRepMikeDoyle',
#  'Sheila_Jackson_Lee': 'JacksonLeeTX18',
#  'Zoe_Lofgren': 'RepZoeLofgren',
#  'Mac_Thornberry': 'MacTXPress',
#  'Elijah_Cummings': 'RepCummings',
#  'Earl_Blumenauer': 'repblumenauer',
#  'Robert_Aderholt': 'Robert_Aderholt',
#  'Kevin_Brady': 'RepKevinBrady',
#  'Danny_K._Davis': 'RepDannyDavis',
#  'Diana_DeGette': 'RepDianaDeGette',
#  'Kay_Granger': 'RepKayGranger',
#  'Ron_Kind': 'RepRonKind',
#  'Jim_McGovern_(American_politician)': 'RepMcGovern',
#  'Bill_Pascrell': 'BillPascrell',
#  'Brad_Sherman': 'BradSherman',
#  'John_Shimkus': 'RepShimkus',
#  'Adam_Smith_(politician)': 'RepAdamSmith',
#  'Gregory_Meeks': 'RepGregoryMeeks',
#  'Barbara_Lee': 'RepBarbaraLee',
#  'Steve_Chabot': 'RepSteveChabot',
#  'Joe_Crowley': 'JoeCrowleyNY',
#  'John_B._Larson': 'RepJohnLarson',
#  'Grace_Napolitano': 'gracenapolitano',
#  'Jan_Schakowsky': 'janschakowsky',
#  'Mike_Simpson': 'CongMikeSimpson',
#  'Mike_Thompson_(California_politician)': 'RepThompson',
#  'Greg_Walden': 'repgregwalden',
#  'Lacy_Clay': 'LacyClayMO1',
#  'Susan_Davis_(politician)': 'RepSusanDavis',
#  'Sam_Graves': 'RepSamGraves',
#  'James_Langevin': 'JimLangevin',
#  'Rick_Larsen': 'RepRickLarsen',
#  'Betty_McCollum': 'BettyMcCollum04',
#  'Adam_Schiff': 'RepAdamSchiff',
#  'Pat_Tiberi': 'PatTiberi',
#  'Stephen_F._Lynch': 'RepStephenLynch',
#  'Joe_Wilson_(American_politician)': 'RepJoeWilson',
#  'Rob_Bishop': 'RepRobBishop',
#  'Michael_C._Burgess': 'michaelcburgess',
#  'John_Carter_(Texas_politician)': 'JudgeCarter',
#  'Tom_Cole': 'TomColeOK04',
#  'Raúl_Grijalva': 'RepRaulGrijalva',
#  'Steve_King': 'SteveKingIA',
#  'Tim_Murphy_(American_politician)': 'RepGregMurphy',
#  'Devin_Nunes': 'RepDevinNunes',
#  'Mike_Rogers_(Alabama_politician)': 'RepMikeRogersAL',
#  'Dutch_Ruppersberger': 'Call_Me_Dutch',
#  'Tim_Ryan_(politician)': 'RepTimRyan',
#  'Linda_Sánchez': 'RepLindaSanchez',
#  'David_Scott_(Georgia_politician)': 'repdavidscott',
#  'Mike_Turner': 'RepMikeTurner',
#  'G._K._Butterfield': 'GKButterfield',
#  'Emanuel_Cleaver': 'repcleaver',
#  'Mike_Conaway': 'ConawayTX11',
#  'Jim_Costa': 'RepJimCosta',
#  'Henry_Cuellar': 'RepCuellar',
#  'Jeff_Fortenberry': 'JeffFortenberry',
#  'Virginia_Foxx': 'virginiafoxx',
#  'Louie_Gohmert': 'replouiegohmert',
#  'Al_Green_(politician)': 'RepAlGreen',
#  'Brian_Higgins': 'RepBrianHiggins',
#  'Dan_Lipinski': 'RepLipinski',
#  'Kenny_Marchant': 'RepKenMarchant',
#  'Michael_McCaul': 'RepMcCaul',
#  'Patrick_McHenry': 'PatrickMcHenry',
#  'Cathy_McMorris_Rodgers': 'cathymcmorris',
#  'Gwen_Moore': 'RepGwenMoore',
#  'Debbie_Wasserman_Schultz': 'RepDWStweets',
#  'Doris_Matsui': 'DorisMatsui',
#  'Albio_Sires': 'RepSires',
#  'Gus_Bilirakis': 'RepGusBilirakis',
#  'Vern_Buchanan': 'VernBuchanan',
#  'Kathy_Castor': 'USRepKCastor',
#  'Yvette_Clarke': 'RepYvetteClarke',
#  'Steve_Cohen': 'RepCohen',
#  'Joe_Courtney_(politician)': 'RepJoeCourtney',
#  'Hank_Johnson': 'RepHankJohnson',
#  'Jim_Jordan_(American_politician)': 'Jim_Jordan',
#  'Doug_Lamborn': 'RepDLamborn',
#  'Dave_Loebsack': 'daveloebsack',
#  'Kevin_McCarthy_(California_politician)': 'GOPLeader',
#  'Jerry_McNerney': 'RepMcNerney',
#  'Ed_Perlmutter': 'RepPerlmutter',
#  'Pete_Roskam': 'PeterRoskam',
#  'John_Sarbanes': 'RepSarbanes',
#  'Adrian_Smith_(politician)': 'RepAdrianSmith',
#  'Tim_Walz': 'Tim_Walz',
#  'Peter_Welch': 'PeterWelch',
#  'John_Yarmuth': 'RepJohnYarmuth',
#  'Bob_Latta': 'boblatta',
#  'Rob_Wittman': 'RobWittman',
#  'André_Carson': 'RepAndreCarson',
#  'Jackie_Speier': 'RepSpeier',
#  'Steve_Scalise': 'SteveScalise',
#  'Marcia_Fudge': 'RepMarciaFudge',
#  'Gerry_Connolly': 'GerryConnolly',
#  'Brett_Guthrie': 'RepGuthrie',
#  'Jim_Himes': 'jahimes',
#  'Duncan_D._Hunter': 'Rep_Hunter',
#  'Blaine_Luetkemeyer': 'RepBlaine',
#  'Ben_Ray_Luján': 'repbenraylujan',
#  'Tom_McClintock': 'RepMcClintock',
#  'Pete_Olson': 'RepPeteOlson',
#  'Chellie_Pingree': 'chelliepingree',
#  'Bill_Posey': 'congbillposey',
#  'Phil_Roe_(politician)': 'DrPhilRoe',
#  'Kurt_Schrader': 'RepSchrader',
#  'Glenn_Thompson_(politician)': 'CongressmanGT',
#  'Paul_Tonko': 'RepPaulTonko',
#  'Mike_Quigley_(politician)': 'RepMikeQuigley',
#  'Judy_Chu': 'RepJudyChu',
#  'John_Garamendi': 'RepGaramendi',
#  'Ted_Deutch': 'RepTedDeutch',
#  'Tom_Graves': 'RepTomGraves',
#  'Tom_Reed_(politician)': 'RepTomReed',
#  'Tim_Walberg': 'RepWalberg',
#  'Bill_Foster_(politician)': 'RepBillFoster',
#  'Justin_Amash': 'justinamash',
#  'Karen_Bass': 'RepKarenBass',
#  'Mo_Brooks': 'RepMoBrooks',
#  'Larry_Bucshon': 'RepLarryBucshon',
#  'David_Cicilline': 'davidcicilline',
#  'Rick_Crawford_(politician)': 'RepRickCrawford',
#  'Scott_DesJarlais': 'DesJarlaisTN04',
#  'Jeff_Duncan_(politician)': 'RepJeffDuncan',
#  'Chuck_Fleischmann': 'RepChuck',
#  'Bill_Flores': 'RepBillFlores',
#  'Bob_Gibbs': 'RepBobGibbs',
#  'Paul_Gosar': 'RepGosar',
#  'Morgan_Griffith': 'RepMGriffith',
#  'Andy_Harris_(politician)': 'RepAndyHarrisMD',
#  'Vicky_Hartzler': 'RepHartzler',
#  'Jaime_Herrera_Beutler': 'HerreraBeutler',
#  'Bill_Huizenga': 'RepHuizenga',
#  'Bill_Johnson_(Ohio_politician)': 'RepBillJohnson',
#  'Bill_Keating_(politician)': 'USRepKeating',
#  'Mike_Kelly_(Pennsylvania_politician)': 'MikeKellyPA',
#  'Adam_Kinzinger': 'RepKinzinger',
#  'Billy_Long': 'USRepLong',
#  'David_McKinley': 'RepMcKinley',
#  'Steven_Palazzo': 'CongPalazzo',
#  'Cedric_Richmond': 'RepRichmond',
#  'Martha_Roby': 'RepMarthaRoby',
#  'Dennis_Ross_(politician)': 'RepRossSpano',
#  'David_Schweikert': 'RepDavid',
#  'Austin_Scott_(politician)': 'AustinScottGA08',
#  'Terri_Sewell': 'RepTerriSewell',
#  'Steve_Stivers': 'RepSteveStivers',
#  'Scott_Tipton': 'RepTipton',
#  'Daniel_Webster_(Florida_politician)': 'RepWebster',
#  'Frederica_Wilson': 'RepWilson',
#  'Steve_Womack': 'rep_stevewomack',
#  'Rob_Woodall': 'RepRobWoodall',
#  'Mark_Amodei': 'MarkAmodeiNV2',
#  'Suzanne_Bonamici': 'RepBonamici',
#  'Suzan_DelBene': 'RepDelBene',
#  'Thomas_Massie': 'RepThomasMassie',
#  'Dina_Titus': 'repdinatitus',
#  'Andy_Barr_(American_politician)': 'RepAndyBarr',
#  'Joyce_Beatty': 'RepBeatty',
#  'Ami_Bera': 'RepBera',
#  'Susan_Brooks': 'SusanWBrooks',
#  'Julia_Brownley': 'RepBrownley',
#  'Cheri_Bustos': 'RepCheri',
#  'Tony_Cárdenas': 'RepCardenas',
#  'Matt_Cartwright': 'RepCartwright',
#  'Joaquín_Castro': 'JoaquinCastrotx',
#  'Doug_Collins_(politician)': 'RepDougCollins',
#  'Paul_Cook_(politician)': 'RepPaulCook',
#  'Rodney_Davis_(politician)': 'RodneyDavis',
#  'Lois_Frankel': 'RepLoisFrankel',
#  'Tulsi_Gabbard': 'TulsiPress',
#  'Dennis_Heck': 'RepDennyHeck',
#  'George_Holding': 'RepHolding',
#  'Richard_Hudson_(American_politician)': 'RepRichHudson',
#  'Jared_Huffman': 'RepHuffman',
#  'Hakeem_Jeffries': 'RepJeffries',
#  'Joe_Kennedy_III': 'RepJoeKennedy',
#  'Dan_Kildee': 'RepDanKildee',
#  'Derek_Kilmer': 'RepDerekKilmer',
#  'Ann_McLane_Kuster': 'RepAnnieKuster',
#  'Doug_LaMalfa': 'RepLaMalfa',
#  'Alan_Lowenthal': 'RepLowenthal',
#  'Sean_Patrick_Maloney': 'RepSeanMaloney',
#  'Mark_Meadows_(North_Carolina_politician)': 'RepMarkMeadows',
#  'Grace_Meng': 'RepGraceMeng',
#  'Markwayne_Mullin': 'RepMullin',
#  'Scott_Perry_(politician)': 'RepScottPerry',
#  'Scott_Peters_(politician)': 'RepScottPeters',
#  'Mark_Pocan': 'repmarkpocan',
#  'Tom_Rice': 'RepTomRice',
#  'Keith_Rothfus': 'RothfusForPA',
#  'Raul_Ruiz_(politician)': 'CongressmanRuiz',
#  'Chris_Stewart_(politician)': 'RepChrisStewart',
#  'Eric_Swalwell': 'RepSwalwell',
#  'Mark_Takano': 'RepMarkTakano',
#  'Juan_Vargas': 'RepJuanVargas',
#  'Marc_Veasey': 'RepVeasey',
#  'Ann_Wagner': 'RepAnnWagner',
#  'Jackie_Walorski': 'RepWalorski',
#  'Randy_Weber': 'TXRandy14',
#  'Brad_Wenstrup': 'RepBradWenstrup',
#  'Roger_Williams_(American_politician)': 'RepRWilliams',
#  'Ted_Yoho': 'RepTedYoho',
#  'Robin_Kelly': 'RepRobinKelly',
#  'Jason_Smith_(politician)': 'RepJasonSmith',
#  'Katherine_Clark': 'RepKClark',
#  'Bradley_Byrne': 'RepByrne',
#  'Donald_Norcross': 'DonaldNorcross',
#  'Ralph_Abraham_(politician)': 'RepAbraham',
#  'Pete_Aguilar': 'RepPeteAguilar',
#  'Rick_W._Allen': 'RepRickAllen',
#  'Brian_Babin': 'RepBrianBabin',
#  'Don_Beyer': 'RepDonBeyer',
#  'Mike_Bost': 'RepBost',
#  'Brendan_Boyle': 'RepBrendanBoyle',
#  'Ken_Buck': 'RepKenBuck',
#  'Buddy_Carter': 'RepBuddyCarter',
#  'Mark_DeSaulnier': 'RepDeSaulnier',
#  'Debbie_Dingell': 'RepDebDingell',
#  'Tom_Emmer': 'RepTomEmmer',
#  'Ruben_Gallego': 'RepRubenGallego',
#  'Garret_Graves': 'RepGarretGraves',
#  'Glenn_Grothman': 'RepGrothman',
#  'Jody_Hice': 'CongressmanHice',
#  'French_Hill_(politician)': 'RepFrenchHill',
#  'Will_Hurd': 'HurdOnTheHill',
#  'John_Katko': 'RepJohnKatko',
#  'Brenda_Lawrence': 'RepLawrence',
#  'Ted_Lieu': 'RepTedLieu',
#  'Barry_Loudermilk': 'RepLoudermilk',
#  'John_Moolenaar': 'RepMoolenaar',
#  'Alex_Mooney': 'RepAlexMooney',
#  'Seth_Moulton': 'sethmoulton',
#  'Dan_Newhouse': 'RepNewhouse',
#  'Gary_Palmer_(politician)': 'USRepGaryPalmer',
#  'John_Ratcliffe_(American_politician)': 'RepRatcliffe',
#  'Kathleen_Rice': 'RepKathleenRice',
#  'David_Rouzer': 'RepDavidRouzer',
#  'Elise_Stefanik': 'RepStefanik',
#  'Norma_Torres': 'NormaJTorres',
#  'Mark_Walker_(North_Carolina_politician)': 'RepMarkWalker',
#  'Bonnie_Watson_Coleman': 'RepBonnie',
#  'Bruce_Westerman': 'RepWesterman',
#  'Lee_Zeldin': 'RepLeeZeldin',
#  'Trent_Kelly': 'RepTrentKelly',
#  'Darin_LaHood': 'RepLaHood',
#  'Warren_Davidson': 'WarrenDavidson',
#  'James_Comer_(politician)': 'KYComer',
#  'Dwight_Evans_(politician)': 'RepDwightEvans',
#  'Brad_Schneider': 'RepSchneider',
#  'Jodey_Arrington': 'RepArrington',
#  'Don_Bacon_(politician)': 'RepDonBacon',
#  'Jim_Banks': 'RepJimBanks',
#  'Nanette_Barragán': 'RepBarragan',
#  'Jack_Bergman': 'RepJackBergman',
#  'Andy_Biggs': 'RepAndyBiggsAZ',
#  'Lisa_Blunt_Rochester': 'RepLBR',
#  'Anthony_G._Brown': 'RepAnthonyBrown',
#  'Ted_Budd': 'RepTedBudd',
#  'Salud_Carbajal': 'RepCarbajal',
#  'Liz_Cheney': 'RepLizCheney',
#  'Lou_Correa': 'RepLouCorrea',
#  'Charlie_Crist': 'RepCharlieCrist',
#  'Val_Demings': 'RepValDemings',
#  'Neal_Dunn': 'DrNealDunnFL2',
#  'Adriano_Espaillat': 'RepEspaillat',
#  'Drew_Ferguson_(politician)': 'RepDrewFerguson',
#  'Brian_Fitzpatrick_(American_politician)': 'RepBrianFitz',
#  'Matt_Gaetz': 'RepMattGaetz',
#  'Mike_Gallagher_(American_politician)': 'RepGallagher',
#  'Josh_Gottheimer': 'RepJoshG',
#  'Clay_Higgins': 'RepClayHiggins',
#  'Trey_Hollingsworth': 'RepTrey',
#  'Pramila_Jayapal': 'RepJayapal',
#  'Mike_Johnson_(Louisiana_politician)': 'RepMikeJohnson',
#  'Ro_Khanna': 'RepRoKhanna',
#  'Raja_Krishnamoorthi': 'CongressmanRaja',
#  'David_Kustoff': 'RepDavidKustoff',
#  'Al_Lawson': 'RepAlLawsonJr',
#  'Roger_Marshall_(politician)': 'RepMarshall',
#  'Brian_Mast': 'RepBrianMast',
#  'Donald_McEachin': 'RepMcEachin',
#  'Paul_Mitchell_(politician)': 'RepPaulMitchell',
#  'Stephanie_Murphy': 'RepStephMurphy',
#  "Tom_O'Halleran": 'RepOHalleran',
#  'Jimmy_Panetta': 'RepJimmyPanetta',
#  'Jamie_Raskin': 'RepRaskin',
#  'Francis_Rooney': 'RepRooney',
#  'John_Rutherford_(Florida_politician)': 'RepRutherfordFL',
#  'Lloyd_Smucker': 'RepSmucker',
#  'Darren_Soto': 'RepDarrenSoto',
#  'Thomas_Suozzi': 'RepTomSuozzi',
#  'Scott_Taylor_(politician)': 'RepVanTaylor',
#  'Ron_Estes': 'RepRonEstes',
#  'Jimmy_Gomez': 'RepJimmyGomez',
#  'Ralph_Norman': 'RepRalphNorman',
#  'John_Curtis_(American_politician)': 'RepJohnCurtis',
#  'Conor_Lamb': 'RepConorLamb',
#  'Debbie_Lesko': 'RepDLesko',
#  'Michael_Cloud': 'RepCloudTX',
#  'Troy_Balderson': 'RepBalderson'}

# %% [markdown]
# *define a function to check if the original authors of a person's retweets are members of the house:*

# %%
def check_if_member(tup):
    
    # initialize a list that only stores retweets whose original author is a member of the house 
    retweets_list = []
    
    # iterate through the reweets tuple and examine the original author of each retweet
    for grp in tup:
        
        # add to the list if original author is a member
        if grp[0] in tw_name:
            retweets_list.append(grp)
            
    return retweets_list

# %% [markdown]
# *define a function to find and filter ALL members' retweets:*

# %%
def process_all():
    
    # initialize a dictionary that stores the Wikipedia name of the member, 
    # the author of his/her retweets (must be a house member too), and the content of these retweets.
    # format: {houseMember1 : [(originalAuthor1, content1),(...,...),...],  houseMember2 : [(...,...),(...,...),...],  ...}
    retweets_dict = {}
    
    # iterate through every file in the directory
    for file in glob.glob("tweets_2019/*"):
        
        # find the retweet list of each house member
        retweets_list = check_if_member(find_retweets(file))
        
        # extract the name of the house member
        tw_name = wikiname_twName_dic[file[12:]]
        
        # append the name and retweets info to the dictionary
        retweets_dict[tw_name] = retweets_list
    
    return retweets_dict

# %% [markdown]
# *finally, build the full dictionary*

# %%
retweets_full_dict = process_all()
retweets_full_dict
# Out:
# {'NormaJTorres': [('SpeakerPelosi',
#    'I am deeply concerned that the White House has canceled an all-Member classified briefing on the dangerous situation the…')],
#  'RepJimCosta': [('RepThompson',
#    'I joined 213 of my colleagues to demand McConnell immediately call the Senate back and pass #HR8 and #HR1112, two bipartis…')],
#  'RepTomSuozzi': [('CongressmanRaja',
#    'Please join us tomorrow for the launch of our new Caucus to End the Youth Vaping Epidemic. It is an honor to lead this…'),
#   ('JeffFortenberry',
#    'With Congressman Tom Suozzi of New York.  @RepTomSuozzi #DDay75thAnniversary #UtahBeach https://t.co/pL91DaEFYY'),
#   ('RepBrianFitz',
#    '.@RepTomSuozzi and I joined local labor leaders at Boilermakers Local 13 to discuss the need for enforcement of labor law…')],
#  'RepBeatty': [('RepLBR',
#    'Soaring drug prices touch everyone’s wallets, from millennials to middle-aged parents to seniors.  America’s patients and taxpa…'),
#   ('RepMarciaFudge',
#    "I'm proud to join @RepMarcyKaptur, @RepBeatty, &amp; @RepTimRyan in sending a letter to Gov. DeWine urging him to oppose th…"),
#   ('RepThompson',
#    'For 203 days, @senatemajldr has refused to hold a vote on #HR8, a bipartisan bill to help prevent gun violence. Thousands…')],
#  'RepBillJohnson': [('GOPLeader',
#    'We are calling up a resolution that condemns Chairman Adam Schiff and the way he has abused his power to mislead the America…'),
#   ('SteveScalise',
#    'People should not be personally targeted for their political views. Period. This isn’t a game. It’s dangerous, and lives…'),
#   ('DrPhilRoe',
#    'Great news for our #BlueWater Vets! The Blue Water Navy Act just passed the Senate!')],
#  'RepMcGovern': [('SpeakerPelosi',
#    'What the @HouseGOP fears the most is the truth. Instead of discussing the facts, they choose to attack @RepAdamSchiff.…'),
#   ('RepMarciaFudge',
#    'The Administration is pushing three rule changes to SNAP that would cause nearly 4 million people to lose access to foo…'),
#   ('SpeakerPelosi',
#    'On one side, you have a repressive regime crushing democratic freedoms in #HongKong. On the other, you have young people…'),
#   ('RepLBR',
#    'Soaring drug prices touch everyone’s wallets, from millennials to middle-aged parents to seniors.  America’s patients and taxpa…'),
#   ('SpeakerPelosi',
#    '.@realDonaldTrump &amp; Admin officials are engaged in a cover-up. It is that simple. #TruthExposed https://t.co/bhIOuXxuXa'),
#   ('RepValDemings',
#    'A question for my GOP colleagues: would you accept foreign interference in your own election? Would you ask for it?'),
#   ('RepRaskin',
#    'Proud to introduce our #RankedChoiceVoting bill to make America’s elections fairer, more efficient, more positive &amp; more rep…'),
#   ('RepDianaDeGette',
#    'Insulin prices are out of control, and families across America are struggling because of it. We need to pass the #Lowe…'),
#   ('RepKClark', 'Actually, they can. And we are. '),
#   ('RepThompson',
#    'For 203 days, @senatemajldr has refused to hold a vote on #HR8, a bipartisan bill to help prevent gun violence. Thousands…'),
#   ('RepRaulGrijalva',
#    'Yesterday we passed @RepCunningham and @USRepKCastor &amp; @RepRooney’s bills to #ProtectOurCoast from offshore drilling.…'),
#   ('RepLindaSanchez',
#    'Hey @KatyTurNBC, as one of only a few Members of Congress to give birth while in office, I know just how difficult it…')],
#  'RepClayHiggins': [('RepMarkMeadows',
#    'Bob Mueller was just asked if his investigation was ever hindered or limited, as Democrats keep baselessly saying it wa…'),
#   ('SteveScalise',
#    'Great to see @TABASCO representing Louisiana at the @WhiteHouse’s #MadeinAmerica showcase. Hope you enjoyed this taste of…'),
#   ('GOPLeader',
#    "It's never been more obvious → House Dems are playing politics with our border crisis. Speaker Pelosi should allow a CLEAN V…"),
#   ('GOPLeader', 'The border crisis BY THE NUMBERS:'),
#   ('SteveScalise',
#    'Democrats\' new "Dream Act" is only a dream for criminals:'),
#   ('RepGarretGraves',
#    "With the potential of the Morganza Spillway being opened, Rep Higgins and I are working with federal, state (gov's off…"),
#   ('GOPLeader',
#    'Democrats did not design #HR1 to protect your vote. They designed it to put a thumb on the scale of every election in Americ…'),
#   ('SteveScalise',
#    "Backed by the strong leadership of @RepClayHiggins, this decision will strengthen Louisiana's economy, create new jobs, a…")],
#  'RepAnnaEshoo': [('RepJohnLarson',
#    'Social Security is the nation’s premiere insurance program, providing economic security for millions of Americans. It’s…'),
#   ('RepZoeLofgren',
#    'My joint statement with @RepJimmyPanetta on the #GilroyShooting: https://t.co/5KX3bkvNOi '),
#   ('RepThompson',
#    'ICYMI I joined with @RepAnnaEshoo to introduce the WIRED Act, a bill that will give states like ours the tools needed to h…'),
#   ('RepJudyChu',
#    "This false claim that Trump doesn't need Congressional approval to start a war with #Iran is exactly why we need bills like…"),
#   ('SpeakerPelosi',
#    'This week, the House will pass legislation to strengthen protections for Americans with pre-existing conditions in the f…'),
#   ('RepDonBeyer',
#    'For years Republicans have punished federal employees with political attacks, pay freezes, and Trump’s shutdowns.'),
#   ('RepVeasey',
#    "2.2M low-income households are among those at risk of eviction because of Trump's shutdown, including housing for veterans,…"),
#   ('BobbyScott',
#    'There is no place in America where someone working full time &amp; making the $7.25 federal minimum wage can make ends meet. To…')],
#  'RepRickCrawford': [('RepMikeTurner',
#    ".@HouseDemocrats' impeachment process is being done in secret, which I believe is a violation of the Constitution &amp; the…"),
#   ('RepLizCheney',
#    ".@RepStefanik is right: The Democrats' closed-door impeachment inquiry has been an unfair and unprecedented process that…"),
#   ('SteveScalise',
#    '🚨 BREAKING → I just asked the Democrat Majority a simple yes or no question: Has the House been authorized to conduct an…'),
#   ('GOPLeader',
#    'Speaker Pelosi and Chairman Schiff just doubled down on their plan to sneak impeachment past the American people:'),
#   ('GOPLeader',
#    'Schiff’s own tweet from August 28th—4 weeks before the transcript was even released. How much did he coordinate with the so-…'),
#   ('GOPLeader',
#    'Chairman Adam Schiff has been lying to the American people for years. His latest setup is no different. His coordination wit…'),
#   ('GOPLeader',
#    'President @realDonaldTrump is right to call out this rushed process because Democrats refuse to protect the transparency and…'),
#   ('GOPLeader',
#    'House Democrats have wanted to undo the results of the 2016 election for three years, and now they’re rushing a sham impeach…'),
#   ('RepRatcliffe',
#    'Since the ICIG has no evidence whatsoever about the relationship and contacts between the whistleblower and Schiff’s staf…'),
#   ('Jim_Jordan',
#    'The facts we learned today from Ambassador Volker undercut the salacious narrative that @RepAdamSchiff is using to sell his…'),
#   ('RepDougCollins',
#    'House Democrat “investigations” further reveal “impeachment” as a sham. The House hasn’t authorized a formal impeachmen…'),
#   ('Jim_Jordan',
#    'Last week, @SpeakerPelosi said "we have to strike while the iron is hot." And she tasked @RepAdamSchiff to do exactly that.…'),
#   ('SteveScalise',
#    'Since LITERALLY DAY 1, Democrats have been trying to impeach @realDonaldTrump. '),
#   ('GOPLeader',
#    'Schiff told the media on September 17: “We have not spoken directly with the whistleblower. We would like to.”'),
#   ('RepDevinNunes',
#    'We learn from the press today that Chm Schiff had prior knowledge and involvement in the WB complaint. He withheld this…'),
#   ('GOPLeader',
#    'BREAKING --&gt; Chairman Adam Schiff just got caught orchestrating with the whistleblower before the complaint was ever filed.…'),
#   ('GOPLeader',
#    'The only thing Democrat leaders care about is politics, not facts. Remember when they USED to believe that impeachment was i…'),
#   ('GOPLeader',
#    'Whistleblowers were required to provide direct, first-hand knowledge of allegations...but just days before the Ukraine whist…'),
#   ('GOPLeader',
#    '@realDonaldTrump @JudiciaryGOP @HouseGOP Every Member of Congress should go on record to say where they stand on Speaker Pel…'),
#   ('SteveScalise',
#    'Dems launched an impeachment inquiry based on a rumor instead of waiting for the facts.'),
#   ('RepRichHudson',
#    'I had a great time playing in the 10th Annual @CongFootball Game last night! This year’s game help raised more than $300…'),
#   ('GOPLeader', 'Here are the facts:'),
#   ('SteveScalise',
#    'Speaker Pelosi is reckless and wrong to call for the impeachment of @realDonaldTrump based on unconfirmed, secondhand acc…'),
#   ('RepLizCheney',
#    'Speaker Pelosi and the House Democrats have abdicated their duty to the Constitution and to the American people by launch…'),
#   ('RepFrenchHill', 'Fixed it for you @washingtonpost '),
#   ('GOPLeader',
#    'Eighteen years ago, terrorists tried to destroy our way of life. Instead, the world saw us come together in a tremendous sho…'),
#   ('SteveScalise',
#    'Democrats are again out of touch with the American people.'),
#   ('RepWesterman',
#    'All smiles witnessing Arkansas and USFS entering a Shared Stewardship agreement. The US government cannot possibly overse…'),
#   ('RepWesterman',
#    "Great news for the commercial trucking industry. I sponsored the HOURS Act last Congress with @RepRickCrawford, and I'm g…")],
#  'RepWilson': [('SpeakerPelosi',
#    'Thank you to @RepWilson for inviting me to join today’s roundtable in Miami to discuss the current unrest in Haiti with…'),
#   ('RepWilson',
#    'President Trump would rather take the U.S. to war with Iran than face impeachment by Democrats. https://t.co/9Kyd8NcDyr'),
#   ('RepWilson',
#    'Is the president trying to escape #impeachment by slow-walking the U.S. into a war with Iran? Inquiring minds want to know!…'),
#   ('RepBarbaraLee',
#    'Tonight I led a special order hour on the House Floor observing 400 years since the first slave ships arrived in Virgini…')],
#  'RepDwightEvans': [('RepDwightEvans',
#    'Today @RepMarkTakano and I introduced a bill to ensure people who are released from prison could obtain proper state ID…'),
#   ('RepDwightEvans',
#    'You may know @RepAdamSchiff from his Intelligence Committee &amp; impeachment inquiry work –'),
#   ('RepMarciaFudge',
#    'The President’s comparison of congressional oversight to the history of heinous acts of racial terrorism inflicted on A…'),
#   ('RepDwightEvans', 'Constituency Spotlight 🚨🚨'),
#   ('RepDwightEvans', 'NEWS: '),
#   ('RepDwightEvans', '#Philly, we have got to change this.'),
#   ('RepDwightEvans', 'The 2020 Census is quickly approaching. '),
#   ('RepLBR',
#    ". @EnergyCommerce is marking up H.R. 3 to lower the cost of prescription drugs - but we're doing so with heavy hearts at the pa…"),
#   ('repjohnlewis',
#    'The American people have lost a great leader at a time of crisis in our democracy.  Chairman Elijah Cummings gave all he…'),
#   ('RepDwightEvans',
#    'I have long worked to reduce hunger both here in America &amp; around the world. '),
#   ('RepDwightEvans',
#    'These workers put in a hard day’s work and deserve fair pay &amp; decent working conditions. '),
#   ('RepMarkTakano', 'This is the GOP before Trump versus now. '),
#   ('RepDwightEvans',
#    'As I have advocated since 2017, @HouseDemocrats are doing an #ImpeachmentInquiry.'),
#   ('RepDwightEvans',
#    'We made it clear with the Constitution that was written &amp; proclaimed in #Philadelphia:'),
#   ('RepDwightEvans',
#    'Thank you to @dc21iupat, which will provide free repairs to North Philly homes damaged by bullets during an August stan…'),
#   ('RepDwightEvans',
#    'Attention #PHLed students: There’s now less than a month left to submit your entry for the Congressional App Challenge!…'),
#   ('RepDwightEvans',
#    'The Senate should join the House in passing the #RaiseTheWage Act! https://t.co/VLE33T8KLx'),
#   ('RepDwightEvans', '@RepMcClinton @RepFiedler 2/'),
#   ('RepDwightEvans', '1/'),
#   ('RepDwightEvans',
#    'The Trump administration is trying for the 3rd time to cut food stamps (SNAP).'),
#   ('RepDwightEvans',
#    'Today #SCOTUS will hear arguments on whether #LGBTQ Americans should be included in legal protections against discrimin…'),
#   ('RepJeffries', 'Is this guy kidding?'),
#   ('RepKinzinger',
#    'I have visited nations ravaged by civil war. @realDonaldTrump I have never imagined such a quote to be repeated by a Pres…'),
#   ('RepDwightEvans',
#    'I’ll be LIVE @onWURD with Cody Anderson tomorrow from 7:30 to 9 AM, reporting to you on what’s happening in DC!'),
#   ('RepAdamSchiff',
#    'Democracy does not mean that you can use military aid as leverage over another country to secure help in an election.'),
#   ('RepDwightEvans',
#    'I proudly voted for the #SAFEBankingAct last night to help #marijuana businesses operate legally.'),
#   ('RepRobinKelly',
#    'Gun violence isn’t simply 100 deaths/day. It’s also 230+ Americans who are shot, wounded &amp; their lives are changed forev…'),
#   ('LeaderHoyer',
#    'The @WaysMeansCmte is holding an important hearing on the public health consequences of gun violence in our country. House…'),
#   ('RepDwightEvans', 'It’s a good day for rolling back Prohibition! '),
#   ('RepRonEstes',
#    'I introduced a bipartisan bill with @RepDwightEvans to address shortages of CNAs. '),
#   ('RepDwightEvans',
#    'In announcing the formal #impeachment inquiry, @SpeakerPelosi recalled what Benjamin Franklin said at the end of the co…')],
#  'RepCummings': [('SpeakerPelosi',
#    'I couldn’t agree more, @RepCummings. The times have found us: we have a duty to delve into the unanswered questions abou…')],
#  'RepChrisSmith': [],
#  'RepRichHudson': [('GOPLeader',
#    'JUST NOW ➜ 185 Republicans voted to move forward to condemn and censure Chairman Adam Schiff. Democrats instead chose to put…'),
#   ('RepArrington',
#    'It’s been 308 days since @realdonaldtrump signed the #USMCA - what have @HouseDemocrats been up to? 🤔 https://t.co/atZP3e…'),
#   ('SteveScalise', 'We have the transcript.'),
#   ('GOPLeader', 'Here are the facts:'),
#   ('RepRichHudson',
#    "Just sent @nchsaa a letter questioning the recent probation of North Stanly High School cheerleaders. I'm appalled these…"),
#   ('RepJeffDuncan',
#    "#gopHEAT Members blast Democrats' short-sighted energy bills w/ @SteveScalise, @RepMullin, @RepLarryBucshon, @RepDanCren…"),
#   ('SteveScalise', 'America’s economy is strong 💪'),
#   ('GOPLeader',
#    'Democrats’ minimum wage plan will erase up to 3.7 million American jobs—hitting low and middle-income families the worst.…')],
#  'RepJimmyGomez': [],
#  'RepPaulCook': [('cathymcmorris',
#    'Tune in at 10 AM as @RepPaulCook joins @HouseGOP leadership to talk about why we are voting again to provide funding cer…'),
#   ('GOPLeader',
#    'Our first line of defense in the fight against terrorism is intelligence. Today the House passed a bill to help identify thr…')],
#  'JudgeCarter': [('GOPLeader', 'Democrats are voting this week to↴'),
#   ('GOPLeader',
#    "I'm calling on Speaker Pelosi to stop playing politics and let the House vote on the bipartisan Senate bill that will provid…"),
#   ('RepRickLarsen',
#    'Today, the House passed my bill w/@JudgeCarter to protect survivor benefits for children of servicemembers who have died…')],
#  'RepChuck': [('RepRWilliams',
#    '.@SpeakerPelosi announced there won’t be a floor vote on the impeachment inquiry – proving once again that this is a sham…'),
#   ('GOPLeader', 'A lot has changed since 1994. Our trade deals should too.'),
#   ('GOPLeader',
#    'BREAKING --&gt; Chairman Adam Schiff just got caught orchestrating with the whistleblower before the complaint was ever filed.…'),
#   ('SteveScalise',
#    '🚨🚨 House Democrats just voted to prioritize health care for illegal immigrants over health care for our veterans. What a…'),
#   ('CongPalazzo',
#    'My friend @SteveScalise called out the Democrats for playing hide and seek with socialism. '),
#   ('GOPLeader',
#    'Last month, Mexico became our top trading partner. Canada is 2nd. China is 3rd.'),
#   ('RepDavidKustoff',
#    'Great jobs numbers! Thanks to @realDonaldTrump’s policies, 195,000 jobs were added to the economy in August— beating t…'),
#   ('GOPLeader',
#    'The United States joins hands with the people of Hong Kong as they peacefully ask the world to hear their hopes for freedom.…'),
#   ('SteveScalise',
#    '🚨🚨 Wages are rising even faster than expected for hardworking Americans.'),
#   ('GOPLeader',
#    'America is WINNING ⇨ 5.6 million jobs created since January 2017! 🇺🇸🇺🇸🇺🇸https://t.co/syhL6twhbZ')],
#  'RepBuddyCarter': [('GOPLeader',
#    'Heading to the House floor at noon ET to call for the censure of Chairman Adam Schiff. Tune in here: https://t.co/Pk4jPUtJIS'),
#   ('SteveScalise', 'The Adam Schiff playbook:'),
#   ('GOPLeader', '🚨 Unemployment just dropped to a 50-YEAR-LOW—3.5%.🚨'),
#   ('RepJohnCurtis',
#    'I’ll be joining @RepBuddyCarter on stage to discuss what issues are priorities for young Americans and what qualities yo…'),
#   ('RepMullin',
#    'And for the low price of $70,000+ a year, you can have the government control nearly every aspect of your life! #GreenNewDis…'),
#   ('RepDougCollins',
#    'Another Democrat theory shot down, and the truth we’ve known for months reaffirmed: https://t.co/vFvNn8MvbL'),
#   ('GOPLeader',
#    'BREAKING → Democrats are trying to vote to impeach the president right now. For what?! Record unemployment. High wages. Limi…')],
#  'RepHuffman': [('RepJeffries',
#    'Deeply saddened by the passing of Chairman Elijah Cummings. '),
#   ('RepLindaSanchez',
#    'As part of its anti-immigrant agenda, the Trump admin. wants to strip rights from immigration judges. It’s never been…'),
#   ('RepRaulGrijalva',
#    'Protecting the @GrandCanyonNPS shouldn’t be up for debate, but the Trump admin doesn’t see it that way.'),
#   ('RepDeSaulnier',
#    'I am proud to partner with @RepJoshHarder, @RepHuffman, @RepRoKhanna, @JimLangevin, and @RepPressley in introducing impo…'),
#   ('RepAdamSchiff',
#    'The presidential oath of office requires the President of the United States to do two things:'),
#   ('RepBonamici',
#    'Today the @IPCC_CH released a Special Report on the Ocean and Cryosphere in a Changing Climate. The findings are dire. The…'),
#   ('RepThompson',
#    'Spoke today about why Congress must reauthorize the North American Wetlands Conservation Act to help conserve public lands…'),
#   ('RepThompson',
#    'For 203 days, @senatemajldr has refused to hold a vote on #HR8, a bipartisan bill to help prevent gun violence. Thousands…'),
#   ('RepDWStweets',
#    'Republicans hid a provision in the GOP #TaxScam that clears the way for oil drilling in the Arctic National Wildlife Refu…'),
#   ('gracenapolitano',
#    'We’re continuing to #StandWithTheGwichin and calling on the Trump administration to stop wreaking havoc in Alaska’s Ar…'),
#   ('RepRaulGrijalva',
#    'Yesterday we passed @RepCunningham and @USRepKCastor &amp; @RepRooney’s bills to #ProtectOurCoast from offshore drilling.…'),
#   ('USRepKCastor',
#    '#ProtectOurCoast Alert❗️We cannot risk another oil drilling disaster off our coasts. Today, the House will vote on my bip…'),
#   ('RepMarkTakano',
#    'This week marks the beginning of National Suicide Prevention Awareness Month. With 20 veterans, servicemembers, reservis…'),
#   ('RepJerryNadler',
#    'Given that Special Counsel Mueller was unable to pursue criminal charges against the President, it falls to Congress to…'),
#   ('RepAdamSchiff',
#    'Regardless of whether the obstructive acts described by Mueller was criminal or whether the litany of illicit contacts w…')],
#  'BennieGThompson': [('SpeakerPelosi',
#    'Each time we visit our troops in Afghanistan, I am struck by the courage &amp; dedication with which they carry out the U.S.…'),
#   ('RepCohen',
#    'Today I joined @RepLoisFrankel &amp; @BennieGThompson in introducing the Trump’s Heist Undermines the G-7 (THUG) Act. This would…'),
#   ('SpeakerPelosi',
#    'Every time we meet with students &amp; families, we hear the same thing: college is far from being affordable. Now we are pu…'),
#   ('RepJeffries', "“Grab 'em by the pu*%y” (women)."),
#   ('RepJeffries', '14 days?'),
#   ('RepLindaSanchez',
#    'Hey @KatyTurNBC, as one of only a few Members of Congress to give birth while in office, I know just how difficult it…'),
#   ('RepBarbaraLee',
#    'Tonight I led a special order hour on the House Floor observing 400 years since the first slave ships arrived in Virgini…'),
#   ('JacksonLeeTX18',
#    'Today, as a senior member of @HomelandDems I traveled to Pittsburgh, home of the #TreeofLife synagogue, to discuss the…'),
#   ('repjohnlewis',
#    '56 years ago today, we Marched on Washington for Jobs and Freedom. Today we continue to fight for the progress we sought…'),
#   ('RepBonnie',
#    'Who are they kidding? #TrumpRecession https://t.co/wqkk8rfPW4 https://t.co/LvBNl0k3Ho'),
#   ('RepBarbaraLee',
#    'This is on the Senate. @HouseDemocrats passed bills to strengthen background checks six months ago. Mitch McConnell need…'),
#   ('RepKClark',
#    'The House passed two gun safety bills months ago, but you continue to block them.'),
#   ('RepDWStweets',
#    '.@BennieGThompson and I wrote the President a letter demanding he take this threat seriously &amp; designate an official to c…')],
#  'RepTrentKelly': [],
#  'RepSamGraves': [('RepBrianBabin',
#    '.@RepSamGraves nailed it in his Op-Ed describing why the #GDN would be disastrous for America. With a price tag of $93T…'),
#   ('RepFrenchHill',
#    'I’m proud to work with my House colleagues @repcleaver and @RepSamGraves to ensure that all who served in WWI are honore…')],
#  'RepStefanik': [('RepRutherfordFL',
#    "2/ I am a cosponsor of @RepStefanik's Canadian Snowbird Visa Act, which will boost our tourism-based economy by allowi…")],
#  'replouiegohmert': [('RepAndyBiggsAZ',
#    'Thank you, @replouiegohmert, for your support of my motion to condemn and censure Adam Schiff. https://t.co/1ZchwIdUlV'),
#   ('RepMoBrooks',
#    'Thanks @replouiegohmert, @RepMGriffith, @RepTedYoho, @RepChipRoy, @congbillposey, @RepAndyHarrisMD, @CongressmanHice, @Rep…'),
#   ('RepAndyBiggsAZ',
#    'Leading a group of my colleagues to Adam Schiff’s secret hearing room to demand answers and transparency. https://t.co/…'),
#   ('RepGosar',
#    '.@replouiegohmert is right: @realDonaldTrump absolutely has a constitutional duty to enforce our immigration laws. https://t.…')],
#  'RepLeeZeldin': [('GOPLeader',
#    'To the thousands of young people in Hong Kong who are speaking UP for human rights and speaking OUT against the Communist Pa…')],
#  'RepBobGibbs': [('RepRatcliffe',
#    'So Schiff claims outrage and alleges a White House "cover-up" to not notify Congress of the whistleblower complaint when…'),
#   ('RepSamGraves',
#    'Today the House passed the Coast Guard Authorization Act—funding the Coast Guard for the next two years.'),
#   ('GOPLeader',
#    'BREAKING NEWS —&gt; Speaker Pelosi just broke the rules of the House, and is no longer permitted to speak on the floor of the H…'),
#   ('GOPLeader',
#    'House Democrats are not trying to solve the humanitarian crisis. Their plan: '),
#   ('GOPLeader',
#    'You and other Democrats have blocked funding 17 times for humanitarian aid at the border. Want to end the crisis? Fund @HHSG…'),
#   ('GOPLeader',
#    'JUST NOW → for the 50th time, House Republicans asked for an up or down vote on the #BornAlive Abortion Survivors Protection…'),
#   ('GOPLeader',
#    'Democrats plan to take over the Internet. Republicans have a better idea. ⤵️ https://t.co/QeRISIjd0h'),
#   ('SteveScalise',
#    '🚨 BREAKING → House Republicans just formed a long line on the House Floor to sign my discharge petition that will force a…'),
#   ('RepAnnWagner',
#    '#LetUsVote to protect babies who are born-alive. The Born Alive Abortion Survivors Protection Act mandates lifesaving med…'),
#   ('RepBradWenstrup',
#    '#SinceGOPTaxCuts American #SmallBiz job creation broke the 45-year record. #TheMoreYouKnow'),
#   ('RepAdrianSmith', '#SinceGOPTaxCuts ')],
#  'RepLarryBucshon': [('GOPLeader',
#    'Here are just a few things Democrats are NOT doing as they pursue their sham process of impeachment:'),
#   ('GOPLeader',
#    'Reminder → Democrats have already voted (and failed) THREE TIMES to try to impeach this president—twice before the Mueller R…'),
#   ('RepRatcliffe',
#    'Since the ICIG has no evidence whatsoever about the relationship and contacts between the whistleblower and Schiff’s staf…'),
#   ('RepLeeZeldin',
#    'Amb Volker just put a dagger in the heart of Schiff’s fairy tale claims of quid pro quo. While House Democrats may prefer…'),
#   ('SteveScalise',
#    "The fix is in. This impeachment scheme is all about politics for Democrats. They're trying to rig 2020 against @realDonal…"),
#   ('GOPLeader',
#    "Every time Democrats have attempted a coup, there's been a common denominator—the lies of Chairman Adam Schiff."),
#   ('GOPLeader',
#    'BREAKING --&gt; Chairman Adam Schiff just got caught orchestrating with the whistleblower before the complaint was ever filed.…'),
#   ('GOPLeader',
#    'If Adam Schiff knew about the whistleblower complaint before it was ever filed, is that why Speaker Pelosi decreed impeachme…'),
#   ('GOPLeader',
#    'House Democrats are only concerned with speed—not facts. Their impeachment efforts have always been a political pursuit to u…'),
#   ('GOPLeader', 'These are the most important facts we have:'),
#   ('SteveScalise',
#    "I won't let the media get away with reciting Democrat talking points."),
#   ('GOPLeader', 'Here are the facts:')],
#  'RepMcClintock': [],
#  'RepGraceMeng': [('LeaderHoyer',
#    'Happy birthday to my friend from #NY06, @RepGraceMeng. Thanks for your work as a member of @AppropsDems and for being a ch…')],
#  'RepRichardNeal': [('SpeakerPelosi',
#    'Americans shouldn’t pay more for their prescriptions than people in other countries. @HouseDemocrats are preparing to in…'),
#   ('RepMcGovern',
#    'Today, @NBA hero and @Holy_Cross alum Bob Cousy will receive the Presidential Medal of Freedom. Bob is an inspiration to m…'),
#   ('SpeakerPelosi',
#    'In February, @HouseDemocrats passed #HR8 &amp; #HR1112 to end gun violence. Today, 175 days have passed &amp; McConnell continue…'),
#   ('LeaderHoyer',
#    'Today, the House took action to protect the pensions of 1.3M Americans &amp; ensure they receive the benefits they’ve earned.…')],
#  'GKButterfield': [('RepMarciaFudge',
#    'The President’s comparison of congressional oversight to the history of heinous acts of racial terrorism inflicted on A…'),
#   ('RepBobbyRush',
#    'You think this impeachment is a LYNCHING? What the hell is wrong with you? '),
#   ('RepJeffries',
#    'Deeply saddened by the passing of Chairman Elijah Cummings. '),
#   ('RepDavidEPrice',
#    'This morning, I was delighted to join my colleague @GKButterfield in celebrating the dedication of the United States Co…'),
#   ('SpeakerPelosi',
#    'This is a very sad time for our country. Investigating a president for impeachment is not a joyful thing. Yet @realDonal…'),
#   ('SpeakerPelosi',
#    'It doesn’t get more serious than this. It is a betrayal of his oath of office for President Trump to pressure a foreign…'),
#   ('RepAdamSchiff',
#    'Democracy does not mean that you can use military aid as leverage over another country to secure help in an election.'),
#   ('RepAdamSchiff',
#    'The President’s suggestion that those involved in the whisteblower complaint should be dealt with as "we used to do" for…'),
#   ('LeaderHoyer',
#    'This @sandyhook PSA is a powerful reminder of the reality of gun violence in our country and the lives at stake. It is lon…'),
#   ('RepThompson',
#    'For 203 days, @senatemajldr has refused to hold a vote on #HR8, a bipartisan bill to help prevent gun violence. Thousands…'),
#   ('SpeakerPelosi',
#    'Members of Congress are coming together in front of the U.S. Capitol to mark a moment of silence, eighteen years after t…'),
#   ('SpeakerPelosi',
#    'The unimaginable loss and unforgettable heroism of #September11 are forever etched into the memory of every American who…'),
#   ('RepMarkTakano',
#    'This week marks the beginning of National Suicide Prevention Awareness Month. With 20 veterans, servicemembers, reservis…'),
#   ('SpeakerPelosi',
#    'Today, as we mark 99 years since the ratification of the #19thAmendment, we celebrate the progress forged by generations…'),
#   ('RepJerryNadler',
#    'Denying green cards to immigrants who are here lawfully solely because they have participated in public health &amp; nutrit…'),
#   ('RepEspaillat',
#    '#TrumpAdministration = heartless, cold, inhumane, reckless'),
#   ('RepMcGovern',
#    '.@SenateMajLdr Mitch McConnell must call the Senate back into session to allow a vote on the commonsense, bipartisan gun v…'),
#   ('RepTerriSewell',
#    '54 years ago today the Voting Rights Act became law. Today, its legacy is under attack as states pass strict voter ID l…'),
#   ('SpeakerPelosi',
#    'In February, the new Democratic House Majority promptly did its duty and passed the Bipartisan Background Checks Act of…'),
#   ('RepAdamSchiff', '.@RepCummings is the conscience of our caucus. '),
#   ('RepCummings',
#    'Mr. President, I go home to my district daily. Each morning, I wake up, and I go and fight for my neighbors.'),
#   ('SpeakerPelosi',
#    '.@RepCummings is a champion in the Congress and the country for civil rights and economic justice, a beloved leader in B…'),
#   ('RepTedBudd',
#    'On stage with my @HBCUCaucus colleagues @GKButterfield, @RepMarkWalker, and @RepFrenchHill at the #DITSummit2019.'),
#   ('CongressmanRuiz',
#    'In the United States of America, when children die on our watch, we take action.'),
#   ('SpeakerPelosi',
#    'A short time ago, I certified to the US Attorney the House’s vote to hold @SecretaryRoss and Attorney General Barr in co…'),
#   ('RepJeffries',
#    'Preparing for the hearing on Wednesday #Mueller #FollowTheFacts https://t.co/sohIGrkOL3'),
#   ('SpeakerPelosi',
#    'Today, a bipartisan agreement has been reached that will enhance our national security &amp; invest in middle class prioriti…'),
#   ('SpeakerPelosi',
#    'The House will now move swiftly to bring the budget caps and debt ceiling agreement legislation to the Floor, so that it…'),
#   ('SpeakerPelosi',
#    'Read my full statement with @SenSchumer here: https://t.co/R395IIqwLT'),
#   ('BobbyScott',
#    'After more than 10 years without an increase in the federal minimum wage, Democrats will vote today to pass the #RaiseTheWa…'),
#   ('SpeakerPelosi',
#    'Mark your calendars: tomorrow, the House will pass the #RaiseTheWage Act. By gradually raising the federal minimum wage…'),
#   ('SpeakerPelosi',
#    'When @realDonaldTrump tells four American Congresswomen to go back to their countries, he reaffirms his plan to “Make Am…'),
#   ('RepMaloney',
#    'We, as a nation, have a moral obligation to honor the men &amp; women who, on Sept. 11th selflessly dropped everything to take…'),
#   ('SpeakerPelosi',
#    'Congrats to @uswnt for winning w/ strength, unity &amp; patriotism. By popular, bipartisan demand &amp; with @USRepKCastor &amp; @Re…'),
#   ('RepJeffries',
#    'Thanks to the leadership of @NYGovCuomo &amp; support from @NatlParkService, the Shirley Chisolm State Park in Brooklyn is now…'),
#   ('SpeakerPelosi',
#    '.@realDonaldTrump continues to make grandiose claims – but anyone looking can tell he’s working hard to keep the public…'),
#   ('RepZoeLofgren',
#    'America’s elections are at the very core of our democracy. We must do all we can to ensure they truly represent the will…'),
#   ('RepBeatty',
#    'We’re all set to take the fight for the #TubmanTwenty to the @USTreasury!'),
#   ('RepBeatty',
#    'Americans want Harriet Tubman  on the #New20, but @stevenmnuchin1 and @realDonaldTrump nixed that plan. That’s  why I introd…')],
#  'RepJoeWilson': [('RepPaulMitchell',
#    'Excited to introduce this #bipartisan bill with @RepSpanberger @RepJoeWilson @GerryConnolly to help #military families…'),
#   ('RepJohnYarmuth',
#    'Proud to join @RepJoeWilson, veteran services organizations, &amp; passionate advocates for a press conf. to provide an upd…'),
#   ('RepJohnYarmuth',
#    'Together with @RepJoeWilson, @TAPSorg, @military_family, @VFWHQ, and more, we will work to repeal the unfair SBP-DIC of…'),
#   ('CongPalazzo',
#    "I was happy to join @RepJoeWilson's #NationalRightToWork Act as an original co-sponsor this week. Over 80% of the American…"),
#   ('RepKenBuck',
#    'No worker should be forced to pay dues or fees to a union just to get or keep a job. That’s why I’ve joined my colleagues a…'),
#   ('RepTedYoho',
#    'I supported @RepJoeWilson, alongside 52 of my colleagues today, in introducing the #NationalRightToWork Act. This legislati…')],
#  'LeaderHoyer': [('RepAnthonyBrown',
#    'Wondering what’s broken in Washington? House Democrats have passed a historic number of bills that Mitch McConnell gle…'),
#   ('BobbyScott',
#    'Today, House Democrats are introducing the #CollegeAffordabilityAct, a comprehensive overhaul of higher education that will…'),
#   ('RepLBR',
#    'Soaring drug prices touch everyone’s wallets, from millennials to middle-aged parents to seniors.  America’s patients and taxpa…'),
#   ('RepDianaDeGette',
#    'Insulin prices are out of control, and families across America are struggling because of it. We need to pass the #Lowe…'),
#   ('JoaquinCastrotx',
#    'Latino Americans are teachers, soldiers, marchers, and leaders. But most importantly, we are members of this American…')],
#  'RepBrianBabin': [('RepLizCheney',
#    'Our opposition to our socialist colleagues isn’t because of their race, religion, or gender. It’s because their policies…'),
#   ('RepBrianBabin',
#    "@KellyO @realDonaldTrump @KellyO you missed something - the @dcexaminer article (by @Anna_Giaritelli) we're handing out…"),
#   ('RepAndyBiggsAZ',
#    'This year, @CBP agents took @RepBrianBabin, @RepTedBudd, Rep. Gianforte, @replouiegohmert, @RepGosar, @RepMGriffith, @R…'),
#   ('SteveScalise',
#    '🚨 BREAKING → House Republicans just formed a long line on the House Floor to sign my discharge petition that will force a…'),
#   ('RepRatcliffe',
#    'From beginning to end, Ralph Hall lived one of the most extraordinary and remarkable lives of anyone ever to serve in Con…')],
#  'JimPressOffice': [('RepGrothman',
#    'This week @SpeakerPelosi is bringing important issues to the House Floor… 13 post office naming bills. 😑 '),
#   ('RepGrothman',
#    'I wish my friend, @JimPressOffice, the very best in retirement and appreciate his years of guidance and service to Wiscons…'),
#   ('BobbyScott',
#    'I wish Congressman Jim Sensenbrenner all the best as he enters this new chapter of his life. @JimPressOffice '),
#   ('RepDougCollins',
#    '.@JimPressOffice\xa0is already a legend in\xa0@JudiciaryGOP\xa0and the House. For 4 decades, he has legislated boldly while hold…'),
#   ('RepScottPerry',
#    'Special thanks to @Douglas_Collins, @replouiegohmert &amp; Rep. Jim Sensenbrenner @JimPressOffice for urging Judiciary Commi…'),
#   ('GOPLeader',
#    'The flags fly at half-staff in memory of the more than 100 law enforcement officers who died in the line of duty last year.…'),
#   ('RepDougCollins',
#    '.@JimPressOffice: It is absolutely shocking that the majority of this committee is going to ask the chief law enforceme…'),
#   ('RepDougCollins',
#    'Wise words from three-time chairman of House Judiciary, @JimPressOffice. https://t.co/XKksnZ0DGr'),
#   ('RepAnnieKuster',
#    'Proud to join @JimPressOffice @RepAnnaEshoo @RepJeffDuncan &amp; @RepZoeLofgren to introduce bipartisan legislation to exem…'),
#   ('RepBradWenstrup',
#    '"This question goes beyond the long-standing debate over whether abortion is moral...We’re not debating that. In this…'),
#   ('RepRonKind',
#    'Today, I partnered with @JimPressOffice and @SenatorTester to introduce a bipartisan, bicameral bill that brings scientists…'),
#   ('RepGrothman',
#    'Welcome back Dean @JimPressOffice - great to hear your stories again! https://t.co/nIwXEeJmUu')],
#  'RepTomReed': [('RepJoshG',
#    'Online radicalization is on the rise around the world. @RepTomReed, @RepBrianFitz, &amp; I sent a letter this morning to social m…'),
#   ('RepKevinBrady',
#    'Thanks to #GOPTaxReform, Social Security’s solvency is improving.'),
#   ('RepTimRyan',
#    'The lack of access to capital negatively impacts US manufacturing’s ability to modernize equipment, grow businesses &amp; creat…'),
#   ('RepRonEstes',
#    'Canada &amp; Mexico buy more products manufactured in America than our next 10 trading partners. This is one more reason why S…'),
#   ('MikeKellyPA',
#    'Mexico ratified #USMCA and is working to address the border crisis by helping stem the flow of migrants north. We’re getti…'),
#   ('RepLaHood',
#    '#USMCA is a win for family farms across America and will position them as global leaders for years to come. DC must put poli…'),
#   ('MikeKellyPA',
#    'Witness at W&amp;M Cmte hearing just said that bureaucrats in Washington will decide who is eligible for treatments and that i…'),
#   ('RepKevinBrady', 'More great economic news!! Recent @Gallup poll shows...'),
#   ('MikeKellyPA',
#    'Jobs, Jobs, Jobs! Pennsylvania has the lowest unemployment since 1976 at 3.8%. The Tax Cuts and Jobs Act and President @re…'),
#   ('RepDrewFerguson', 'Economic good news! '),
#   ('RepRonEstes',
#    "Before today's @WaysandMeansGOP hearing on climate change, read my op-ed in @thehill about why we need to encourage innova…"),
#   ('RepDianaDeGette',
#    'It’s hard to get 378 members of Congress to agree on anything. ')],
#  'RepPeteKing': [('RepJoshG',
#    "And thank you to @RepMaloney @RepJerryNadler and @RepPeteKing for their leadership in ensuring we're doing everything to care…"),
#   ('JacksonLeeTX18',
#    'I am here standing with our #FirstResponders ahead of the House vote on H.R. 1327: The #NeverForget the Heroes Act.')],
#  'JimLangevin': [],
#  'daveloebsack': [('RepCheri',
#    'Glad to work with @SenatorDurbin, @SenDuckworth and @daveloebsack to secure a $1.2M grant for @QCMetro to replace an old ferr…')],
#  'RepTedDeutch': [('VernBuchanan',
#    'The U.S. House just passed the #PACT Act, legislation that I introduced with my colleague @RepTedDeutch to criminalize an…'),
#   ('USRepMikeDoyle',
#    'I’m a cosponsor of the #PACTAct, and I’m glad it passed the House today! Currently, there is no law federal against ani…'),
#   ('chelliepingree',
#    '71% of #domesticviolence victims said their abuser also attacked their pets, but did you know that cruelty against anim…'),
#   ('RepScottPeters',
#    'Ending animal abuse is long overdue. I support the #PACTAct to make animal cruelty a federal offense and protect our pe…'),
#   ('repdinatitus',
#    'Did you know that cruelty against animals is NOT a federal offense? Today the House voted to change that by passing the #…'),
#   ('RepJerryNadler',
#    'Some issues aren’t partisan, even in Washington. Proud to support the #PACTAct, which makes animal cruelty a federal cr…'),
#   ('RepDavid',
#    'I am pleased to see the #PACTact pass the House! This legislation will take protecting animals a step further by making extre…'),
#   ('RepFrenchHill',
#    'As a lifelong lover of animals, I’m proud to be a cosponsor of the #PACTact that just passed the House tonight with an o…'),
#   ('RepAnnieKuster',
#    "My boys grew up with our beloved cats, Petey &amp; Pelé. Today, I'm proud to support the #PACTAct to protect pets like them…"),
#   ('RepBrownley',
#    'Animal cruelty is unacceptable in our society. I am proud to support the bipartisan #PACTAct to finally make animal cruelt…'),
#   ('RepCheri',
#    'Animal cruelty is unacceptable in our society. As an animal lover, I’m proud to support the #PACTAct today to make cruelty ag…'),
#   ('RepLoisFrankel',
#    'Ending animal abuse is something we can all agree on. I’m proud to stand with my friend @RepTedDeutch as a co-sponsor o…'),
#   ('RepBarragan', 'Ending animal abuse is long overdue. '),
#   ('RepSchrader',
#    'Did you know that cruelty against animals is NOT a federal offense? Today I will vote to change that by passing the #PACTA…'),
#   ('RepTedBudd',
#    "Today, I'll be proud to support the PACT Act, which imposes strict federal penalties on anyone who engages in animal cruelt…"),
#   ('VernBuchanan',
#    'Torturing innocent animals is abhorrent and should be punished to the fullest extent of the law! @RepTedDeutch and I cont…'),
#   ('RepSusanDavis',
#    "I'll be voting for the #PACTAct today to make animal abuse a federal crime. While making and/or distributing animal crus…"),
#   ('RepHankJohnson',
#    'I support the #PACTAct to make animal cruelty a federal offense for pets in Georgia and our nation as a whole. Animal a…'),
#   ('SpeakerPelosi',
#    "The President's Chief of Staff says there’s “no cover-up.”"),
#   ('RepTedDeutch',
#    'Mulvaney claims that Doral was ”not the only place but the best place” under consideration. '),
#   ('RepTedDeutch',
#    'Vice President Mike Pence doesn’t think that Congress or the American people deserve to know if he was involved in the ef…'),
#   ('RepLindaSanchez',
#    'As part of its anti-immigrant agenda, the Trump admin. wants to strip rights from immigration judges. It’s never been…'),
#   ('davidcicilline',
#    'NEW: Continuing to press for answers today on the President’s inexplicable decision to abandon our Kurdish allies. http…'),
#   ('RepDWStweets',
#    '.@SenRickScott accused Senate Democrats of blocking Temporary Protected Status for Venezuelans (something House Republica…'),
#   ('RepTedDeutch', '.@GovRonDeSantis must be confused. '),
#   ('SpeakerPelosi',
#    'It has been over 200 days since the House passed life-saving background checks legislation. 100 people die every day fro…'),
#   ('RepAdamSchiff',
#    'This complaint should never have been withheld, and it provides a roadmap for our investigation.'),
#   ('RepTedDeutch',
#    'Pres. Trump asked the Ukrainian president to manufacture dirt on his political opponent.'),
#   ('RepTedDeutch',
#    'Pressuring a foreign leader to manufacture dirt about your political opponent may be business as usual for some world lea…'),
#   ('RepTedDeutch',
#    'The President pressured the president of Ukraine to investigate Joe Biden’s son to help his 2020 campaign.  Now he’s bloc…')],
#  'RepJoshG': [],
#  'DrNealDunnFL2': [('DrPhilRoe',
#    '5 members of the Doctors Caucus and I took a trip to the southern border. Read about our visit in our op-ed in @FoxNews here…'),
#   ('GOPLeader',
#    'America is WINNING ⇨ 5.6 million jobs created since January 2017! 🇺🇸🇺🇸🇺🇸https://t.co/syhL6twhbZ'),
#   ('DrPhilRoe',
#    'Want to learn more about what members of the GOP Doctors Caucus saw at our southern border? Watch our video below to hear wh…'),
#   ('DrPhilRoe',
#    'Great to work with you, @DrNealDunnFL2 and @RepJudyChu on this critical legislation! https://t.co/8CDM154kOE'),
#   ('GOPLeader', '74th time ← Democrats blocked @RodneyDavis '),
#   ('GOPLeader',
#    'HAPPENING NOW → Republicans are repeatedly asking Democrats to take up a vote on a bipartisan Senate bill that will provide…'),
#   ('RepTedYoho',
#    "7 months ago Hurricane Michael hit Florida's panhandle &amp; Congress has neglected to act. I stand with @GovRonDeSantis &amp; my F…")],
#  'RepAnnWagner': [('SteveScalise',
#    '🚨 BREAKING: New GOP congressmen Rep Dan Bishop &amp; Rep Greg Murphy signed my discharge petition to force a vote on @RepAnnW…')],
#  'RepMcEachin': [('RepWilson',
#    'Comparing impeachment to a #lynching is one of the most despicable and disgusting things to come out of this president’s mou…'),
#   ('SpeakerPelosi',
#    'What the @HouseGOP fears the most is the truth. Instead of discussing the facts, they choose to attack @RepAdamSchiff.…'),
#   ('RepDebDingell',
#    'Nearly 4.5 million women have reported being threatened with a gun.'),
#   ('BobbyScott',
#    'Today, House Democrats are introducing the #CollegeAffordabilityAct, a comprehensive overhaul of higher education that will…'),
#   ('davidcicilline',
#    'Just a quick reminder about all the bills Mitch McConnell is still blocking. https://t.co/I3kpw2jSoB'),
#   ('RepLindaSanchez',
#    'Hey @KatyTurNBC, as one of only a few Members of Congress to give birth while in office, I know just how difficult it…'),
#   ('USRepLong',
#    'Accurate broadband maps play a critical role in closing the #DigitalDivide. That is why @RepMcEachin and I have introduced t…'),
#   ('RepRaulGrijalva',
#    '2/11 The @washingtonpost got this wrong. My staff took this video in late August. Yes, new wall is being built. Water…'),
#   ('RepEspaillat',
#    '#TrumpAdministration = heartless, cold, inhumane, reckless')],
#  'RepMarkTakano': [('RepDwightEvans',
#    'Today @RepMarkTakano and I introduced a bill to ensure people who are released from prison could obtain proper state ID…'),
#   ('BobbyScott',
#    'Today, House Democrats are introducing the #CollegeAffordabilityAct, a comprehensive overhaul of higher education that will…'),
#   ('RepBillFoster',
#    'Today, I introduced a bill with @RepMarkTakano, @MazieHirono, &amp; @SenThomTillis to improve the Office of Technology Asses…'),
#   ('RepJayapal',
#    'The Trump Administration abandoned the Obama-era overtime rule and it’s costing workers billions of dollars every year. I’m…'),
#   ('rosadelauro',
#    "It has been 15 years since the overtime rule was last updated, and it's costing workers billions every year. I support the…"),
#   ('JacksonLeeTX18',
#    'Workers should not have to keep waiting to see their hard work reflected in their paychecks. The Restoring Overtime Pay…'),
#   ('RepBarbaraLee',
#    'Overtime standards are out-of-date and leaving millions of workers behind. At a time when so many families are strugglin…')],
#  'RepBlaine': [('RepJasonSmith',
#    'Saw these Missouri cows this morning. I didn’t have the heart to tell them their gases are the cause of climate change,…')],
#  'RepAbraham': [('SteveScalise',
#    '🚨 BREAKING → I just asked the Democrat Majority a simple yes or no question: Has the House been authorized to conduct an…'),
#   ('RepDougCollins',
#    'Speaking truth to power is House Members telling the Speaker that the rules of the House apply to the Speaker, too. htt…'),
#   ('GOPLeader',
#    'You and other Democrats have blocked funding 17 times for humanitarian aid at the border. Want to end the crisis? Fund @HHSG…'),
#   ('RepMikeJohnson',
#    'I will be hosting a town hall with @RepAbraham in Leesville on Friday, June 14. This is a great opportunity to voice yo…'),
#   ('RepMikeJohnson', 'Facts matter. https://t.co/0xRF7ZWSsQ'),
#   ('GOPLeader',
#    '19 times ← House Republicans have tried to pass the Born-Alive Abortion Survivors Protection Act, a bill that would rescue c…'),
#   ('SteveScalise',
#    'Glad to see the steel slats are deterring illegal immigrants from attempting to cross the border exactly as @realDonaldTr…'),
#   ('SteveScalise',
#    'Hi @AOC. Happy to continue this debate on the Floor of the People’s House, but it’s clearly not productive to engage here…')],
#  'davidcicilline': [('davidcicilline',
#    'Thanks to my brilliant colleague @RepRaskin for setting the record straight in tomorrow’s @projo! https://t.co/MKVYXxmc…'),
#   ('RepLindaSanchez',
#    'As part of its anti-immigrant agenda, the Trump admin. wants to strip rights from immigration judges. It’s never been…'),
#   ('davidcicilline',
#    'Just a quick reminder about all the bills Mitch McConnell is still blocking. https://t.co/I3kpw2jSoB'),
#   ('RepSchneider',
#    'House Democrats have passed an expansive agenda for the American People, but Leader McConnell is single-handedly blocking…'),
#   ('RepAdamSchiff', 'This is simple.'),
#   ('JimLangevin',
#    'Great to meet with #RI college students studying in DC at our 17th Annual #RI Student Reception with @SenJackReed, @SenWhi…'),
#   ('RepJoeKennedy',
#    'President Trump admitted he tried to coerce a foreign government to investigate a political opponent. Transcript proves…'),
#   ('RepAdamSchiff',
#    'The transcript of the call reads like a classic mob shakedown:'),
#   ('SpeakerPelosi', 'The times have found us. https://t.co/iVNe9nqzx9'),
#   ('RepAdamSchiff',
# ...
#   ('SpeakerPelosi',
#    'The House of Representatives &amp; the American people are well represented by @ClimateCrisis Select Committee Chair @USRepK…')],
#  'RepBrianHiggins': [('RepRichardNeal',
#    'Tomorrow the @WaysMeansCmte will be marking up a number of health care bills to address pathways to health, lowering pr…')],
#  'RepJohnLarson': [('RepThompson',
#    'For 203 days, @senatemajldr has refused to hold a vote on #HR8, a bipartisan bill to help prevent gun violence. Thousands…'),
#   ('RepLindaSanchez',
#    'Hey @KatyTurNBC, as one of only a few Members of Congress to give birth while in office, I know just how difficult it…')],
#  'RepDevinNunes': [],
#  'RepBrianFitz': [('RepConorLamb',
#    'Today the House passed H.R. 2385, my bill with @RepBrianFitz to make it easier for universities to honor the lives &amp; sacr…'),
#   ('RepBillFoster',
#    'Student debt is an economic burden for far too many Americans. Today, I introduced the bipartisan Public Service Loan Fo…'),
#   ('RepAnnieKuster',
#    'Proud to join @RepBrianFitz to advance the RESTORE Act to take a multifaceted approach to fighting the opioid epidemic…'),
#   ('RepLloydDoggett',
#    'NEW: Today, with @RepBrianFitz &amp; @SenBobCasey, I introduced bipartisan Stop the Wait Act—to end the burdensome, danger…'),
#   ('RepJoshG',
#    'Online radicalization is on the rise around the world. @RepTomReed, @RepBrianFitz, &amp; I sent a letter this morning to social m…'),
#   ('RepPeteKing',
#    'This is a great victory, and it’s long overdue. Tremendous credit has to go to all the 9/11 victims and their families who…'),
#   ('RepMaloney',
#    'The U.S. women’s national soccer team could not be a better example of why we need a Women’s History Museum to commemorate…'),
#   ('RepFredUpton',
#    '🚨 Given the humanitarian crisis at the border, the Problem Solvers Caucus is asking for the immediate consideration on th…'),
#   ('RepBonnie',
#    'Yesterday, the House included $10M for the continuing recovery of the Delaware River Basin. The Delaware River is a vital fe…'),
#   ('RepSpeier',
#    'Proud to be joined by @RepBrianFitz @RepAnnieKuster @RepAdams in reintroducing the bipartisan HALT Campus Sexual Violence Ac…')],
#  'RepJimBanks': [('USRepLong',
#    "This is your friendly reminder that it's been 325 days since the USMCA was signed, and the speaker still hasn't brought it u…"),
#   ('SteveScalise',
#    '🚨 BREAKING: I just filed a rules change to allow ALL Members of Congress access to proceedings related to impeachment.'),
#   ('SteveScalise',
#    '🚨 BREAKING → I just asked the Democrat Majority a simple yes or no question: Has the House been authorized to conduct an…'),
#   ('RepLaMalfa',
#    'Today is #BringYourBibletoSchoolDay. Recently, @Saints QB @drewbrees was attacked by the left for encouraging students to p…'),
#   ('GOPLeader',
#    'The Speaker of the House moved to have an impeachment inquiry *before* she read one word of evidence. Now that the transcrip…')],
#  'RepJeffDuncan': [('Jim_Jordan', 'Dems’ impeachment:'),
#   ('RepByrne',
#    'In case you doubted @CNN is #fakenews, they’re now refusing to air @realdonaldtrump’s campaign ads! We can’t look the other w…'),
#   ('RepJeffDuncan',
#    'Chairman Adam Schiff manufactured a false transcript of the call between @POTUS @realDonaldTrump &amp; the Ukrainian Preside…'),
#   ('RepAndyBiggsAZ',
#    '➡️ 184 Members of Congress have cosponsored my motion to condemn and censure Adam Schiff. '),
#   ('RepAndyBiggsAZ',
#    '#FF the Members of Congress who have cosponsored my motion to condemn &amp; censure Adam Schiff: @GOPLeader @SteveScalise @…'),
#   ('RepMoBrooks', 'Thanks @RepRalphNorman, @RepRonWright, @Rep_Hunter, '),
#   ('SteveScalise',
#    '🚨 BREAKING → I just asked the Democrat Majority a simple yes or no question: Has the House been authorized to conduct an…'),
#   ('RepAndyBiggsAZ',
#    '#FF the Members of Congress who have cosponsored my motion to condemn &amp; censure Adam Schiff: @GOPLeader @SteveScalise @…'),
#   ('SteveScalise', 'Nothing to see here... https://t.co/RoZhZj4QfM'),
#   ('RepAndyBiggsAZ',
#    '#FF the Members of Congress who have cosponsored my motion to condemn &amp; censure Adam Schiff: @GOPLeader @SteveScalise @…'),
#   ('RepLeeZeldin',
#    'Amb Volker just put a dagger in the heart of Schiff’s fairy tale claims of quid pro quo. While House Democrats may prefer…'),
#   ('SteveScalise',
#    "The fix is in. This impeachment scheme is all about politics for Democrats. They're trying to rig 2020 against @realDonal…"),
#   ('RepJeffDuncan',
#    'Joined @RepAndyBiggsAZ to condemn &amp; censure House Intelligence Committee Chairman Adam Schiff. Instead of quoting direct…'),
#   ('RepAndyBiggsAZ',
#    'ICYMI: Last week, I introduced a motion to condemn and censure Chairman Adam Schiff.'),
#   ('RepJeffDuncan',
#    'Just like the Russian collusion fairy tale, the Democrats are clinging to the next NON-smoking-gun because they want @PO…'),
#   ('RepJeffDuncan',
#    'There you have it folks–the #witchhunt continues. House Democrats are proceeding on impeachment against @realdonaldtrump…'),
#   ('SteveScalise', 'The Left’s radical climate agenda in action:'),
#   ('RepFrankLucas',
#    'This disruption to the global energy supply network demonstrates the importance of continued U.S. energy independence &amp;…'),
#   ('RepJeffDuncan', 'Happy #ConstitutionDay, America! '),
#   ('RepJohnKatko',
#    'You’re on @RepJeffDuncan!  Ready to support @CuseFootball at tomorrow’s sold-out home opener 🍊 #LetsGoOrange https://t.co…'),
#   ('RepJeffDuncan',
#    'Our economy is booming in large part because of Republicans’ pro-growth approach to energy. As leaders of #gopHEAT we wi…'),
#   ('RepMullin',
#    'Using all of our energy resources means lower costs for families and lower emissions. Our economy is booming thanks to Repub…')],
#  'RepGarretGraves': [],
#  'repjimcooper': [],
#  'RepBarbaraLee': [],
#  'RepRobWoodall': [],
#  'SpeakerPelosi': [('RepLBR',
#    'Soaring drug prices touch everyone’s wallets, from millennials to middle-aged parents to seniors.  America’s patients and taxpa…'),
#   ('RepDianaDeGette',
#    'Insulin prices are out of control, and families across America are struggling because of it. We need to pass the #Lowe…'),
#   ('JoaquinCastrotx',
#    'Latino Americans are teachers, soldiers, marchers, and leaders. But most importantly, we are members of this American…'),
#   ('RepThompson',
#    'For 203 days, @senatemajldr has refused to hold a vote on #HR8, a bipartisan bill to help prevent gun violence. Thousands…'),
#   ('RepRaulGrijalva',
#    'Yesterday we passed @RepCunningham and @USRepKCastor &amp; @RepRooney’s bills to #ProtectOurCoast from offshore drilling.…'),
#   ('USRepKCastor',
#    '#ProtectOurCoast Alert❗️We cannot risk another oil drilling disaster off our coasts. Today, the House will vote on my bip…'),
#   ('RepLipinski',
#    'I spoke out on the floor today about my experience in Gilroy and the demands of #IL03 constituents for commonsense gun leg…'),
#   ('RepVeasey',
#    'More than 90% of the American people agree: it’s time for the Senate to pass the bipartisan #HR8 and expand background check…')],
#  'MarkAmodeiNV2': [('SteveScalise',
#    "Almost 5,000 helicopter pilots and crew members died in the Vietnam War. @MarkAmodeiNV2's bill will create a memorial for…")],
#  'RepDarrenSoto': [('RepDavid',
#    'I wrote a letter with my Congressional Blockchain Caucus Co-Chair @RepDarrenSoto to @US_FDA applauding their new blueprint fo…'),
#   ('RepDWStweets',
#    '.@SenRickScott accused Senate Democrats of blocking Temporary Protected Status for Venezuelans (something House Republica…'),
#   ('RepValDemings',
#    '.@RepDarrenSoto is right. This is larger than politics, and our actions cannot depend on whether the Senate Republicans…')],
#  'RepDennyHeck': [('SpeakerPelosi',
#    'Congratulations to @RepPerlmutter &amp; @RepDennyHeck on a strong bipartisan vote to pass the #SAFEBanking Act, which will a…'),
#   ('RepPerlmutter',
#    '.@RepDennyHeck: "If you want your businesses to be safer, vote yes." '),
#   ('davidcicilline',
#    'Will be joining @HardballChris and @RepDennyHeck in a few minutes on MSNBC to talk about today’s news. https://t.co/sww…'),
#   ('RepAdamSchiff',
#    'Any effort by Trump to pressure a foreign government to dig up dirt on his political opponent, while holding up vital mi…'),
#   ('RepTrey',
#    'ICYMI: I introduced the Yes In My Backyard Act with @RepDennyHeck → https://t.co/jwWYn3xgj8'),
#   ('RepDennyHeck',
#    "@mattyglesias True, on its own the bill won't fix our housing problems, but no one bill will be the perfect fix. It will…"),
#   ('RepScottPeters',
#    'Our bill will enable federal investment in transit to increase housing options for families across the country. It will…'),
#   ('RepAdamSchiff',
#    "Russia attacked our democracy to help Trump win. Trump's campaign welcomed and used that help, and then Trump covered it…"),
#   ('RepAdamSchiff',
#    'Foreign policy is not a photo-op. It’s not reality TV. It takes hard work, planning, and perseverance.'),
#   ('RepPeteAguilar',
#    'Elections are the defining feature of our democracy – and yet there are shockingly few rules in place designed to ensur…'),
#   ('RepAnnieKuster',
#    'Democrats believe in strengthening, not weakening protections for the 130 million Americans living with pre-existing co…'),
#   ('RepAdamSchiff', 'A quick update on our national security leadership:')],
#  'RepMaxineWaters': [],
#  'RepRichmond': [('RepMarkWalker',
#    'Great to be hosting a roundtable discussion on giving #NCAA athletes the right back to their names and likeness with @Ja…'),
#   ('RepBarbaraLee',
#    'Tonight I led a special order hour on the House Floor observing 400 years since the first slave ships arrived in Virgini…'),
#   ('RepKarenBass',
#    'In 2016, Black women made up 6% of the overall workforce, but only 21% of the low-wage and lowest wage workforces. This i…'),
#   ('RepDonBeyer', 'A key exchange just now:'),
#   ('RepGarretGraves',
#    '@RepRichmond and I have introduced legislation to increase offshore energy revenues for La.   We are battling the larg…'),
#   ('RepVeasey',
#    'Congrats to game MVP @RepRichmond and rookie of the year @RepColinAllred! @TheBlackCaucus did well this year! #Congressional…'),
#   ('RepRWilliams',
#    'As someone whose life has been shaped by America’s greatest pastime, I am proud to introduce the Integration of Baseball…'),
#   ('WhipClyburn',
#    'As we celebrate #Juneteenth let us remember that it was lack of communication that gave rise to this celebration. '),
#   ('SteveScalise',
#    '75 years ago, 150,000+ troops risked their lives on #DDay—a mission that turned the tide of WWII. They deserve lasting re…'),
#   ('RepYvetteClarke',
#    'I am a proud founding member of the Black Maternal Health Caucus led by @RepAdams and @RepUnderwood. Black women are 4…'),
#   ('RepCohen',
#    "The housing crisis is serious in #Memphis. 1 in 4 renters pays 50% of their income or more in rent. That’s why I'm pleased to…"),
#   ('RepGwenMoore',
#    "Women are coming together today for the 63rd annual UN session of the #CSW. How fitting that this year's theme of social…"),
#   ('SpeakerPelosi',
#    'Whether they were Jewish, Roma, LGBTQ or one of the many other communities targeted, our duty to remember every soul los…'),
#   ('RepGarretGraves',
#    'ICYMI- yesterday @RepRichmond and I introduced two amendments to further help Louisiana flood victims.  You can read m…'),
#   ('RepYvetteClarke',
#    'Today, @RepRichmond and I led an @OfficialCBC comment letter to @USCIS in opposition to the Trump Administration’s pro…'),
#   ('GKButterfield',
#    'I just informed @Clyburn that our whip team has secured more than enough commitments from Democratic members of the next…')],
#  'RepStephMurphy': [('LeaderHoyer',
#    "Tomorrow, the House will vote on a bipartisan resolution condemning Trump's decision to abandon our Kurdish allies in the…"),
#   ('RepFrenchHill',
#    'Proud to team up with @RepBillFoster @RepSteveChabot @RepStephMurphy @RepDavid @RepVeasey to launch the bipartisan House…')],
#  'RepGuthrie': [('michaelcburgess',
#    'Thank you to @POTUS and @SecAzar for highlighting the importance of vaccines as tools to protect Americans from preven…'),
#   ('repgregwalden',
#    'Eastern Oregon Telecom\'s @joefranell in the @EastOregonian today: "Republicans and Democrats actually agree on the key p…'),
#   ('RepBonamici',
#    'Today I joined @RepGuthrie in promoting workforce development programs by designating September 2018 as National Workforce…'),
#   ('RepPeteAguilar',
#    'Proud to join my friend @RepGuthrie to launch the Congressional E-Commerce Caucus. Looking forward to working on a bipa…'),
#   ('RepAndyBarr',
#    'Ready to board Air Force 2 with @RepGuthrie. We are headed to Lexington with @VP to make the case for repealing and replac…'),
#   ('RepFredUpton',
#    'Great piece from @michaelcburgess &amp; @RepGuthrie on the need to reauthorize FDA’s vitally important user fee programs http…')],
#  'RepScottPerry': [('Jim_Jordan', 'Dems’ impeachment:'),
#   ('RepAndyBiggsAZ',
#    'Adam Schiff may not have been held accountable tonight, but the American people are very much aware of his reckless dis…'),
#   ('RepAndyBiggsAZ',
#    'Nearly two-thirds of the @HouseGOP are now cosponsoring my motion to censure Adam Schiff. Mr. Schiff must be held accou…'),
#   ('GOPLeader',
#    "Our nation's infrastructure is crumbling, and there are bipartisan solutions on the table. But what are Washington Democrats…"),
#   ('SteveScalise',
#    "The fix is in. This impeachment scheme is all about politics for Democrats. They're trying to rig 2020 against @realDonal…"),
#   ('RepAndyBiggsAZ',
#    'ICYMI: Last week, I introduced a motion to condemn and censure Chairman Adam Schiff.'),
#   ('GOPLeader',
#    'Chairman Adam Schiff has been lying to the American people for years. Now he is so desperate to damage the president that he…'),
#   ('GOPLeader',
#    'House Democrats are only concerned with speed—not facts. Their impeachment efforts have always been a political pursuit to u…'),
#   ('CongressmanHice',
#    "As we expose the Democrat collusion delusion in this week's @freedomcaucus podcast, @Jim_Jordan assesses the IG report…"),
#   ('RepMarkMeadows',
#    'Correct. Mueller clarified this exchange just an hour later: he was NOT saying he would charge Trump without the OLC op…'),
#   ('RepMarkMeadows',
#    'REMINDER, 2014: President Obama says asylum claims are not justified by economic need, crime, or poverty.'),
#   ('CongressmanHice',
#    "On this week's podcast, Pennsylvania's @RepScottPerry, retired Brigadier General &amp; whip for the @freedomcaucus, joined…"),
#   ('Jim_Jordan', '#DoWhatWeSaid https://t.co/DGiYw2a3q1'),
#   ('Jim_Jordan', '#DoWhatWeSaid https://t.co/PMlRZ58onO'),
#   ('RepThomasMassie',
#    'I’d rather Congress debate in  broad daylight but if Congress is legislating amendments to an omnibus spending bill at…')],
#  'RepPeteAguilar': [('LeaderHoyer',
#    'Happy birthday to my good friend and Chief Deputy Whip, @RepPeteAguilar. Thank you for your long-time commitment to protec…'),
#   ('RepTedDeutch',
#    'Standing today and always with the community of Parkland and the families of the victims of the MSD shooting as we honor…')],
#  'RepRossSpano': [('RepDarrenSoto',
#    'GREAT NEWS: After 2 years of waiting, Polk County Schools will finally receive funds to recover from damages sustained i…'),
#   ('RepMikeJohnson',
#    "@TeamPelosi RSC's 👏 Health 👏 Care 👏 Plan 👏protects 👏 Americans 👏 with 👏 pre-existing 👏 conditions 👏 better 👏 than 👏 the…"),
#   ('RepThomasMassie',
#    'In July, I reintroduced my bill to assist seniors by eliminating the unjust double-tax on Social Security benefits.')],
#  'RepTomGraves': [('RepDerekKilmer', '🚨Back by popular demand...my podcast!🚨'),
#   ('rep_stevewomack',
#    'My appreciation to Chairman @RepDerekKilmer, Vice Chairman @RepTomGraves &amp; Members of the @ModernizeCmte for inviting…'),
#   ('SteveScalise', 'Another huge jobs report:'),
#   ('GOPLeader',
#    'Republicans are not stopping. We are continuing to demand a vote on a common-sense solution to the crisis at our border. ')],
#  'RepGaramendi': []}

# %% [markdown]
# * **Use a NetworkX [`DiGraph`](https://networkx.github.io/documentation/development/reference/classes.digraph.html) to store the network. Use weighted edges to account for multiple retweets. Also store the party of each member as a node attribute (use the data in [this file](https://github.com/suneman/socialgraphs2019/blob/master/files/data_twitter/H115_tw_2019.csv). Remove self-loops (edges that connect a node with itself).**

# %% [markdown]
# *We want to find the number of re-tweets between two members:*

# %%
# build a dictionary with the following structure
# {(A, B) : n1, (A, C) : n2, (B, D) : n3 , ...}
# meaning that A retweets B for a total of n1 times

graph_dic={}

for k,v in retweets_full_dict.items():
    for pair in v:
        key = (k, pair[0])
        if key in graph_dic:
            graph_dic[key] += 1
        else:
            graph_dic[key] = 1

# %% [markdown]
# *Build a directed graph:*

# %%
def build_Graph():

    # initialize a directed graph
    G=nx.DiGraph()
    
    # add nodes as tw_name and party for each member as node attribute
    for username in tw_name:
        G.add_node(username, party = twName_party_dic[username])
    
    # add edges between members and weight stands for the number of retweets
    for k,v in graph_dic.items():
        G.add_edge(k[0], k[1], weight = v)
    
    # remove self-loop as required
    for node in list(G.nodes):
        try:
            G.remove_edge(node,node)
        except:
            pass
    return G

# %%
G = build_Graph()

# %%
nx.draw_networkx(G)
# Out:
#  46%|████▌     | 4555/10000 [00:38<00:31, 173.99it/s]

# %% [markdown]
# ## Exercise 2: Visualize the network of retweets and investigate differences between the parties

# %% [markdown]
# * Visualize the network using the [Networkx draw function](https://networkx.github.io/documentation/stable/reference/generated/networkx.drawing.nx_pylab.draw.html#networkx.drawing.nx_pylab.draw), and nodes coordinates from the force atlas algorithm. *Hint: use an undirected version of the graph to find the nodes positions for better results, but stick to the directed version for all measurements.* Plot nodes in colors according to their party (e.g. 'red' for republicans and 'blue' for democrats) and set the node-size to be proportional to total degree.

# %% [markdown]
# Map party to color and store in node_color list, according to the sequence in node list.

# %%
# node color list
node_color=list(nx.get_node_attributes(G,'party').values())
node_color=list(map(lambda x : x.replace("Republican", "red"),node_color))
node_color=list(map(lambda x : x.replace("Democratic", "blue"),node_color))

# %% [markdown]
# Find node degree and store in degree_list list, according to the sequence in node list.

# %%
degree_list=list(map(lambda x : x[1], list(G.degree)))

# %% [markdown]
# Adjust the values as proportions to total degree and store in node_size list

# %%
node_size=list(map(lambda x : x/sum(degree_list), degree_list))

# %% [markdown]
# Use Force Atlas algorithm to find the position of undirected version of graph G.

# %%
forceatlas2 = ForceAtlas2(
                        # Behavior alternatives
                        outboundAttractionDistribution=True,  # Dissuade hubs
                        linLogMode=False,  # NOT IMPLEMENTED
                        adjustSizes=False,  # Prevent overlap (NOT IMPLEMENTED)
                        edgeWeightInfluence=0,

                        # Performance
                        jitterTolerance=0.0001,  # Tolerance
                        barnesHutOptimize=True,
                        barnesHutTheta=0.08,
                        multiThreaded=False,  # NOT IMPLEMENTED

                        # Tuning
                        scalingRatio=0.001,
                        strongGravityMode=False,
                        gravity=0,

                        # Log
                        verbose=False)

# %%
positions = forceatlas2.forceatlas2_networkx_layout(G.to_undirected(), 
                                                    pos=None,iterations=10000)

# %% [markdown]
# Visualize the graph.

# %%
nx.draw_networkx(G, positions, 
        node_size=[x*5000 for x in node_size], node_color=node_color,
        node_shape='o',
        width=0.15,
        arrows=False,
        with_labels=False)

# %% [markdown]
# * Compare the network of Retweets with the network of Wikipedia pages (generated during Week 5). Do you observe any differences? How do you explain them?

# %% [markdown]
# We will attach a network of Wikipedia pages generated during week 5.

# %% [markdown]
# ![Screenshot%202019-11-01%20at%2017.23.03.png](attachment:Screenshot%202019-11-01%20at%2017.23.03.png)

# %% [markdown]
# In the network of Wikipedia pages,
# 1. members from two parties are very much interlinked.
# 2. there is no obvious cluster of same party.
# 3. nodes have similar sizes, which means they have similar degree.
#
# In the network of retweets,
# 1. memebers in the same party are interlinked. There are fewer edges connecting memebrs from different parties.
# 2. there are two obvious clusters for each party.
# 3. nodes' sizes vary in a wide range, indicating nodes have a wide range of degree distribution.
#
# Possible explanation include,
# 1. Wikipedia pages are more objective in introducing each member, including debates or even open disagreement between members from two parties. So, as a result, wikipedia network shows more edges connecting two parties.
# 2. memebers from the same party are likely to have more daily interaction and more active in retweeting each other, in order to support for example a party initiative or campaign. Therefore, there are two clusters in retweet network.
# 3. some members use twitter more frequently than others, so they will have a larger node degree than the rest. This explains why nodes in retweet network show a wide range of degree distribution.

# %% [markdown]
# * Now set the node-size tob proportional to betweenness centrality. Do you observe any changes?

# %% [markdown]
# Our group borrows explanation from wikipedia (https://en.wikipedia.org/wiki/Betweenness_centrality).
#
# In graph theory, betweenness centrality is a measure of centrality in a graph based on shortest paths. For every pair of vertices in a connected graph, there exists at least one shortest path between the vertices such that either the number of edges that the path passes through (for unweighted graphs) or the sum of the weights of the edges (for weighted graphs) is minimized.

# %% [markdown]
# Our graph is weighted in which edge weight represents the number of retweets. Based on the definition of betweenness centrality for weighted graph above, we realize that there is no meaning if we add edge weights (total number of retweets). Therefore, we will treat edges have the same weight and focus on detecting the amount of influence a node has over the flow of information in a graph.
#
# Hence, we set weight=None in the below cell.

# %%
betweenness=list(nx.betweenness_centrality(G, weight=None).values())

# %%
nx.draw_networkx(G, positions, 
        node_size=[x*1000 for x in betweenness], node_color=node_color,
        node_shape='o',
        width=0.15,
        arrows=False,
        with_labels=False)
# Out:
# //anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %% [markdown]
# We observe that
# 1. a few nodes positioned in between two clusters have grown in node size. This means they are important in connecting memebers between two parties. They serve as bridges in information flow.
# 2. within each cluster, nodes with larger degree in general will appear bigger in the betweenness plot. This is because due to their greater connection, they appear more often in the shortest path between another two nodes.

# %% [markdown]
# * Repeat the point above using eigenvector centrality. Again, do you see a difference? Can you explain why based on what eigenvector centrality measures?

# %% [markdown]
# Eigenvector centrality measures a node’s importance while giving consideration to the importance of its neighbors. If nodes with high degrees lead to the target node, the target node will have high eigenvector centrality.

# %%
eigenvector=list(nx.eigenvector_centrality(G).values())

# %%
nx.draw_networkx(G, positions, 
        node_size=[x*800 for x in eigenvector], node_color=node_color,
        node_shape='o',
        width=0.15,
        arrows=False,
        with_labels=False)

# %% [markdown]
# We observe that nodes belonging to Republicans have higher eigenvector centrality than those belong to Democrats. This is perhaps because the few republicans with high degrees lead to almost every other republicans. Additionally, republicans are more connected within their cluster. As a result, eigenvector centrality for republicans are high.
#
# Interestingly, President Trump who uses twitter a looooooot is a Republican!

# %% [markdown]
# * Who are the three nodes with highest degree within each party? And wbat is their eigenvector centrality? And their betweenness centrality?

# %%
def get_Top_N(graph,n):
    # sort the graph nodes by their degrees
    sort_degree=sorted(list(G.degree),key=lambda x : x[1],reverse=True)
    
    # add party information into the sorted list
    sort_degree=[x + (twName_party_dic[x[0]],) for x in sort_degree]
    
    # filter republicans and democrats
    rep=[x for x in sort_degree if x[2] == 'Republican']
    demo=[x for x in sort_degree if x[2] == 'Democratic']
    
    print("Top {} nodes with highest degree in Republican".format(n))
    print(rep[:n])
    print("---------------------------------------------------------")
    print("Top {} nodes with highest degree in Democratic".format(n))
    print(demo[:n])
    return None

# %%
get_Top_N(G,3)
# Out:
# Top 3 nodes with highest degree in Republican
# [('GOPLeader', 118, 'Republican'), ('RepAndyBiggsAZ', 97, 'Republican'), ('SteveScalise', 95, 'Republican')]
# ---------------------------------------------------------
# Top 3 nodes with highest degree in Democratic
# [('SpeakerPelosi', 72, 'Democratic'), ('RepLindaSanchez', 36, 'Democratic'), ('RepAdamSchiff', 35, 'Democratic')]

# %% [markdown]
# Extract those 6 members' eigenvector centrality and betweenness centrality.

# %%
nodes_name=['GOPLeader','RepAndyBiggsAZ','SteveScalise',
            'SpeakerPelosi','RepLindaSanchez','RepAdamSchiff']

# %%
print("Their eigenvector centrality are : ")
for item in [(name, nx.eigenvector_centrality(G)[name]) for name in nodes_name]:
    print(item)
# Out:
# Their eigenvector centrality are :
# ('GOPLeader', 0.415531657579665)
# ('RepAndyBiggsAZ', 0.26824828179382637)
# ('SteveScalise', 0.3563102708066077)
# ('SpeakerPelosi', 0.012972287900614736)
# ('RepLindaSanchez', 0.0064014458827216306)
# ('RepAdamSchiff', 0.0072666982858010975)

# %%
print("Their betweenness centrality are : ")
for item in [(name, nx.betweenness_centrality(G)[name]) for name in nodes_name]:
    print(item)
# Out:
# Their betweenness centrality are :
# ('GOPLeader', 0.1729152239843508)
# ('RepAndyBiggsAZ', 0.11055898578473246)
# ('SteveScalise', 0.11684840447572264)
# ('SpeakerPelosi', 0.05225312402691525)
# ('RepLindaSanchez', 0.028066579463347074)
# ('RepAdamSchiff', 0.001299671464006964)

# %% [markdown]
# * Plot (on the same figure) the distribution of outgoing strength for the republican and democratic nodes repectively (i.e. the sum of the weight on outgoing links). Which party is more active in retweeting other members of the house?

# %% [markdown]
# First, get the sum of the weights on outgoing links for all nodes.

# %%
out_weights=list(map(lambda x : (x[0], x[2]['weight']), list(G.edges.data())))
strength_dic={}
for tup in out_weights:
    if tup[0] in strength_dic:
        strength_dic[tup[0]] += tup[1]
    else:
        strength_dic[tup[0]] = tup[1]

# %% [markdown]
# Second, filter republicans and democrats.

# %%
rep_strength={}
demo_strength={}
for (k,v) in strength_dic.items():
    if twName_party_dic[k] == 'Republican':
        rep_strength[k] = v
    else:
        demo_strength[k] = v

# %% [markdown]
# Third, define a bin to be used for both parties (since they have to be on the same plot)

# %%
v=[5*i for i in range(0,25)]

# %% [markdown]
# Finally, plot!

# %%
plt.hist(list(rep_strength.values()), histtype='step', 
         stacked=True, fill=False, bins=v, alpha = 0.8, color="red")
plt.hist(list(demo_strength.values()),histtype='step', 
         stacked=True, fill=False,bins=v,alpha = 0.8, color="blue")
plt.title("Distribution of Outgoing Strength")
plt.xlabel("Outgoing Strength")
plt.ylabel("Number of Members")
plt.show()

# %% [markdown]
# From the plot, the red color (Republicans) are more right-skewed, meaning they are more active in retweeting other members of the house.

# %% [markdown]
# * Find the 3 members of the republican party that have retweeted tweets from democratic members most often. Repeat the measure for the democratic members. Can you explain your results by looking at the Wikipedia pages of these members of the house?

# %% [markdown]
# First, get the number of outgoing strength for all members.

# %%
out_weights=list(map(lambda x : (x[0], x[1], x[2]['weight']), list(G.edges.data())))

# %% [markdown]
# Second, make sure the retweet is between two members from different parties.

# %%
def diff_party(lst):
    rep=[]
    demo=[]
    for tup in lst:
        if twName_party_dic[tup[0]] == 'Republican' and twName_party_dic[tup[1]] != 'Republican':
            rep.append(tup)
        elif twName_party_dic[tup[0]] != 'Republican' and twName_party_dic[tup[1]] == 'Republican':
            demo.append(tup)
    return (rep,demo)

# %%
rep=diff_party(out_weights)[0]
demo=diff_party(out_weights)[1]

# %% [markdown]
# Third, compute the number of retweets from opposite party for each member.

# %%
def retweet_rank(lst):
    dic={}
    for tup in lst:
        if tup[0] in dic:
            dic[tup[0]] += tup[2]
        else:
            dic[tup[0]] = tup[2]
    
    return sorted(list(dic.items()), key=lambda x : x[1], reverse=True)

# %% [markdown]
# Note: there are 7 members having the same rank in republican party.

# %%
print("Top 3 members from republicans who retweet tweets from democrats the most:")
for x in retweet_rank(rep)[:9]:
    print(x)
# Out:
# Top 3 members from republicans who retweet tweets from democrats the most
# ('RepBrianFitz', 8)
# ('RepRooney', 5)
# ('JimPressOffice', 3)
# ('RepFredUpton', 3)
# ('VernBuchanan', 3)
# ('DrPhilRoe', 3)
# ('CongressmanGT', 3)
# ('RepTomReed', 3)
# ('RepPaulMitchell', 3)

# %%
print("Top 3 members from democrats who retweet tweets from republicans the most:")
for x in retweet_rank(demo)[:3]:
    print(x)
# Out:
# Top 3 members from democrats who retweet tweets from republicans the most:
# ('RepMarkGreen', 7)
# ('RepTedDeutch', 5)
# ('RepRichmond', 5)

# %% [markdown]
# ## Exercise 3: Community detection

# %% [markdown]
# * Use your favorite method of community detection to find communities in the full house of representatives network. Report the value of modularity found by the algorithm. Is it higher or lower than what you found for the Wikipedia network (Week 7)? Comment on your result.

# %% [markdown]
# * Visualize the network, using the Force Atlas algorithm. This time assign each node a different color based on their *community*. Describe the structure you observe.

# %% [markdown]
# * Compare the communities found by your algorithm with the parties by creating a matrix $\mathbf{D}$ with dimension $(B \times C$, where $B$ is the number of parties and $C$ is the number of communities. We set entry $D(i,j)$ to be the number of nodes that party $i$ has in common with community $j$. The matrix $\mathbf{D}$ is what we call a [**confusion matrix**](https://en.wikipedia.org/wiki/Confusion_matrix).

# %% [markdown]
# * Use the confusion matrix to explain how well the communities you've detected correspond to the parties. Consider the following questions
#   * Are there any republicans grouped with democrats (and vice versa)?
#   * Does the community detection algorithm sub-divide the parties? Do you know anything about American politics that could explain such sub-divisions? Answer in your own words.

# %% [markdown]
# # Part 2: What do republican and democratic members tweet about?

# %% [markdown]
# ## Exercise 4: TF-IDF of the republican and democratic tweets
# We will create two documents, one containing the words extracted from tweets of republican members, and the other for Democratic members. We will then use TF-IDF to compare the content of these two documents and create a word-cloud. The procedure you should use is exactly the same you used in exercise 2 of week 7. The main steps are summarized below:

# %% [markdown]
# * **Create two large documents, one for the democratic and one for the republican party. Tokenize the pages, and combine the tokens into one long list including all the pages of the members of the same party.**

# %% [markdown]
# *define a function to parse the tweets of ONE member of the house*

# %%
def find_preprocess_tweets(path):
        
    # first, read the tweets of a particular member
    # io module is chosen for its encoding parameter as utf-8 encoding is needed
    text = io.open(path, mode="r", encoding="utf-8").read()
    
    # replace newline character symbols in the text with a space
    text = re.sub(r'\n', ' ', text)
    
    # remove urls in the text
    # urls have little use in gathering insight into house members' tweet patterns
    text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', '', text)
    
    # replace word character symbols in the text with a space
    text = re.sub(r'/w', ' ', text)
        
    return text

# %% [markdown]
# *define a funciton to tokenize text*

# %%
def tokenize(text):
    word_tokens = nltk.tokenize.word_tokenize(text) # tokenize text
    return word_tokens

# %% [markdown]
# **1. Exclude the twitter handles of other members.**

# %% [markdown]
# *We are not quite sure of what this subtask is trying to achieve. If we do as what the task askes for, i.e. remove twitter handles of members of the opposing party, then what are left are:*
# 1. *handles of members of the same party*,
# 2. *handles of users not belonging to any of the parties, and*
# 3. *tweet content*
#
# *Point 1. and 2. are unlikely to give us insight into what the person tweets about, as they are just handles (usernames) which are not part of the tweets.*
# <br>
# <br>
# *Therefore, our group has decided to remove all handles, i.e. `@username` from the text, and focus only on the tweet content itself*
# <br>
# <br>
# *Please let us know if you interpret this subtask in a different way. We'd love to hear your thoughts on this!*

# %%
def exclude_twitter_handles(text):
    
    # remove retweet handles (RT @originalAuthor: )
    text = re.sub('RT @[a-zA-Z0-9_]+: ', '', text)
    
    # remove general 'at's (@username)
    text = re.sub('@[a-zA-Z0-9_]+', '', text)
    
    return text

# %% [markdown]
# **2. Exclude punctuation.**

# %%
# obtain a list of punctuations for later use
punctuations = [i for i in string.punctuation]
punctuations

# %% [markdown]
# **3. Exclude stop words (if you don't know what stop words are, go back and read NLPP1e again).**

# %%
# obtain a list of stop words for later use
stop_words = list(nltk.corpus.stopwords.words('english'))
stop_words

# %% [markdown]
# **4. Exclude numbers (since they're difficult to interpret in the word cloud).**

# %%
# function to check if a string contains numbers
def exclude_numbers(text):
    return re.sub(r'\d', '', text)

# %% [markdown]
# **5. Set everything to lower case.**

# %%
def set_to_lower_case(text):
    return text.lower()

# %% [markdown]
# *putting everything together:*

# %%
# define a function to process tweets of ONE member

def process_one_member(path):
    
    # parse and process the text
    text = find_preprocess_tweets(path) # parse the tweets of ONE member of the house
    text = exclude_twitter_handles(text) # exclude twitter handles
    text = exclude_numbers(text) # exclude numbers
    text = set_to_lower_case(text) # set to lowercase
       
    # add punctuations and stop words to one list
    to_be_removed = punctuations + stop_words
    
    # tokenize the text
    word_tokens = tokenize(text)
        
    # remove punctuations and stop words
    word_tokens = [w for w in word_tokens if not w in to_be_removed]
    
    return word_tokens

# %%
# initialise two empty tokens
democratic_tokens = []
republican_tokens = []

# %%
# define a function to process tweets of ALL members, based on their parties

def process_all_members():
       
    # iterate through all files in the folder
    for file in glob.glob("tweets_2019/*"):
        
        # extract the wikiname of the house member
        name = file[12:]
        
        # obtain the path of each file
        path = "tweets_2019/" + name
        
        # tokenize the tweets of each house member
        word_tokens = process_one_member(path)
        
        # obtain the member's party
        party = wikiName_party_dic[name]
        
        # add his tweets tokens to the respective party token list
        if party == "Democratic":
            democratic_tokens.extend(word_tokens)
#             democratic_documents.append([" ".join(word_tokens),])
        elif party == "Republican":
            republican_tokens.extend(word_tokens)
#             republican_documents.append([" ".join(word_tokens),])

# %%
# run the function to obtain the tokens of democratic tweets and republican tweets
process_all_members()

# %%
democratic_tokens

# %%
republican_tokens

# %% [markdown]
# * Compute the TF-IDF for each document.

# %% [markdown]
# TF (term frequency) is defined to be
#
# count of term in document / number of words in document
#
# tf(t,d) = count of t in d / number of words in d

# %%
def term_frequency(token_list):
    tf={}
    for word in token_list:
        if word in tf:
            tf[word] += 1
        else:
            tf[word] = 1
    for key in tf.keys():
        tf[key] = tf[key]/len(token_list)
    return tf

# %% [markdown]
# IDF (inverse document frequency) is defined to be
#
# log ( Total number of documents / (occurrence term in documents + 1) )
#
# log(N/(df+1))

# %%
def inverse_document_frequency(token_list):
    idf={}
    for word in token_list:
        if word in idf:
            idf[word] += 1
        else:
            idf[word] = 1
    for key in idf.keys():
        idf[key] = math.log(1/(idf[key]+1))
    return idf

# %%
inverse_document_frequency(republican_tokens)

# %% [markdown]
# * Now, create word-cloud for each party. Are these topics less "boring" than the Wikipedia topics from Week 7? Why?  Comment on the results.

# %% [markdown]
# # Part 3: Sentiment analysis

# %% [markdown]
# ## Exercise 5: Sentiment over the Twitter data

# %% [markdown]
# * Download the LabMT wordlist. It's available as supplementary material from [Temporal Patterns of Happiness and Information in a Global Social Network: Hedonometrics and Twitter](http://journals.plos.org/plosone/article?id=10.1371/journal.pone.0026752) (Data Set S1). Describe briefly how the list was generated.

# %% [markdown]
# * Based on the LabMT word list, write a function that calculates sentiment given a list of tokens (the tokens should be lower case, etc).

# %% [markdown]
# * Create two lists: one containing tweets by democratic members, and the other with the tweets of republican members. Calculate the sentiment of each tweet and plot the distribution of sentiment for each of the two lists. Are there significant differences between the two? Which party post more positive tweets?

# %% [markdown]
# * Compute the average $m$ and standard deviation $\sigma$  of the Tweets sentiment (considering tweets by both republican and democrats).

# %% [markdown]
# * Now only tweets with sentiment lower than $m-2\sigma$. We will refer to them as *negative* tweets.  Build a list containing *negative* tweets written by democrats, and one for republicans. Compute the TF-IDF on these two lists. Create a word-cloud for each of them. Are there differences between the positive content posted by republican and democrats?

# %% [markdown]
# * Repeat the point above, but considering _positive_ tweets (e.g. with sentiment larger than $m+2\sigma$). Comment on your results.
